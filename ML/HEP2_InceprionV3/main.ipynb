# %%
from pathlib import Path
from collections import Counter


from sklearn.model_selection import train_test_split

from pathlib import Path
from datetime import datetime
import json

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
    roc_curve,
    auc,
    precision_recall_fscore_support,
    precision_recall_curve,
    average_precision_score
)
from sklearn.preprocessing import label_binarize

# %%
MODEL_SIZE = 512
SEED = 42
FORCE_GRAYSCALE = True

tf.random.set_seed(SEED)
np.random.seed(SEED)

EXPERIMENT_ROOT = Path("experiments")
EXPERIMENT_ROOT.mkdir(exist_ok=True)

RUN_ID = f"InceprionV3_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
EXP_DIR = EXPERIMENT_ROOT / RUN_ID

CHECKPOINT_DIR = EXP_DIR / "checkpoints"
PLOTS_DIR = EXP_DIR / "plots"
REPORTS_DIR = EXP_DIR / "reports"

CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)
PLOTS_DIR.mkdir(parents=True, exist_ok=True)
REPORTS_DIR.mkdir(parents=True, exist_ok=True)

print("Experiment:", RUN_ID)
print("Output directory:", EXP_DIR)
# Out:
# Experiment: InceprionV3_20260419_233606
# Output directory: experiments\InceprionV3_20260419_233606

# %%
DATA_ROOT = Path(r"D:\\cells\\ML\\HEP2_png")

CLASS_NAMES = ["24", "48", "72", "control"]
NUM_CLASSES = len(CLASS_NAMES)
CLASS_TO_IDX = {class_name: idx for idx, class_name in enumerate(CLASS_NAMES)}
IDX_TO_CLASS = {idx: class_name for class_name, idx in CLASS_TO_IDX.items()}

IMG_SIZE = 512
BATCH_SIZE = 8
SEED = 42

# Если RAM мало, можно поставить False
USE_CACHE = True

AUTOTUNE = tf.data.AUTOTUNE

tf.random.set_seed(SEED)
np.random.seed(SEED)

print(CLASS_TO_IDX)
# Out:
# {'24': 0, '48': 1, '72': 2, 'control': 3}

# %%
rows = []

for class_name in CLASS_NAMES:
    class_dir = DATA_ROOT / class_name

    if not class_dir.exists():
        raise FileNotFoundError(f"Не найдена папка класса: {class_dir}")

    image_paths = sorted(class_dir.glob("*.png"))

    if len(image_paths) == 0:
        raise RuntimeError(f"В папке {class_dir} нет PNG-изображений")

    for path in image_paths:
        rows.append({
            "path": str(path),
            "class": class_name,
            "label": CLASS_TO_IDX[class_name]
        })

df = pd.DataFrame(rows)

print("Всего изображений:", len(df))
df.head()
# Out:
# Всего изображений: 827
#                                                 path class  label
# 0  D:\cells\ML\HEP2_png\24\TUC-20251219092727377.png    24      0
# 1  D:\cells\ML\HEP2_png\24\TUC-20251219092733486.png    24      0
# 2  D:\cells\ML\HEP2_png\24\TUC-20251219092737240.png    24      0
# 3  D:\cells\ML\HEP2_png\24\TUC-20251219092741404.png    24      0
# 4  D:\cells\ML\HEP2_png\24\TUC-20251219092745351.png    24      0

# %%
class_counts = (
    df["class"]
    .value_counts()
    .reindex(CLASS_NAMES)
    .fillna(0)
    .astype(int)
)

print(class_counts)
# Out:
# class
# 24         269
# 48         128
# 72          86
# control    344
# Name: count, dtype: int32

# %%
df_train, df_temp = train_test_split(
    df,
    test_size=0.30,
    random_state=SEED,
    stratify=df["label"]
)

df_val, df_test = train_test_split(
    df_temp,
    test_size=0.50,
    random_state=SEED,
    stratify=df_temp["label"]
)

df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

print("train:", len(df_train))
print("val:  ", len(df_val))
print("test: ", len(df_test))
# Out:
# train: 578
# val:   124
# test:  125

# %%
def show_split_distribution(name, split_df):
    counts = (
        split_df["class"]
        .value_counts()
        .reindex(CLASS_NAMES)
        .fillna(0)
        .astype(int)
    )

    print(f"\n{name}")
    print(counts)
    return counts


train_counts = show_split_distribution("TRAIN", df_train)
val_counts = show_split_distribution("VAL", df_val)
test_counts = show_split_distribution("TEST", df_test)
# Out:
# TRAIN
# class
# 24         188
# 48          90
# 72          60
# control    240
# Name: count, dtype: int32
#
# VAL
# class
# 24         40
# 48         19
# 72         13
# control    52
# Name: count, dtype: int32
#
# TEST
# class
# 24         41
# 48         19
# 72         13
# control    52
# Name: count, dtype: int32

# %%
n_train = int(train_counts.sum())
n_classes = len(CLASS_NAMES)

class_weight_dict = {}

for class_name in CLASS_NAMES:
    class_idx = CLASS_TO_IDX[class_name]
    count = int(train_counts[class_name])

    if count == 0:
        raise RuntimeError(f"В train нет изображений класса {class_name}")

    weight = n_train / (n_classes * count)
    class_weight_dict[int(class_idx)] = float(weight)

print("class_weight_dict:")
for idx, weight in class_weight_dict.items():
    print(f"{idx} ({IDX_TO_CLASS[idx]}): {weight:.4f}")
# Out:
# class_weight_dict:
# 0 (24): 0.7686
# 1 (48): 1.6056
# 2 (72): 2.4083
# 3 (control): 0.6021

# %%
def load_image_grayscale_rgb(path, label):
    image_bytes = tf.io.read_file(path)

    image = tf.io.decode_png(
        image_bytes,
        channels=3
    )

    image = tf.cast(image, tf.float32)

    # RGB -> grayscale -> RGB
    # На выходе 3 канала, но изображение остаётся чёрно-белым.
    image = tf.image.rgb_to_grayscale(image)
    image = tf.image.grayscale_to_rgb(image)

    image = tf.image.resize(
        image,
        size=(IMG_SIZE, IMG_SIZE),
        method="bilinear"
    )

    label = tf.cast(label, tf.int32)

    return image, label

# %%
augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.05),
    tf.keras.layers.RandomZoom(0.10),
    tf.keras.layers.RandomTranslation(0.05, 0.05),
    tf.keras.layers.RandomContrast(0.10),
], name="train_augmentation")

# %%
def apply_train_augmentation(images, labels):
    images = augmentation(images, training=True)
    return images, labels

# %%
train_paths = df_train["path"].values
train_labels = df_train["label"].values.astype(np.int32)

val_paths = df_val["path"].values
val_labels = df_val["label"].values.astype(np.int32)

test_paths = df_test["path"].values
test_labels = df_test["label"].values.astype(np.int32)

# %%
train_ds_base = tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
val_ds_base = tf.data.Dataset.from_tensor_slices((val_paths, val_labels))
test_ds_base = tf.data.Dataset.from_tensor_slices((test_paths, test_labels))

# %%
train_ds = train_ds_base.map(
    load_image_grayscale_rgb,
    num_parallel_calls=AUTOTUNE
)

if USE_CACHE:
    train_ds = train_ds.cache()

train_ds = (
    train_ds
    .shuffle(buffer_size=len(df_train), seed=SEED, reshuffle_each_iteration=True)
    .batch(BATCH_SIZE)
    .map(apply_train_augmentation, num_parallel_calls=AUTOTUNE)
    .prefetch(AUTOTUNE)
)

val_ds = val_ds_base.map(
    load_image_grayscale_rgb,
    num_parallel_calls=AUTOTUNE
)

if USE_CACHE:
    val_ds = val_ds.cache()

val_ds = (
    val_ds
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

test_ds = test_ds_base.map(
    load_image_grayscale_rgb,
    num_parallel_calls=AUTOTUNE
)

if USE_CACHE:
    test_ds = test_ds.cache()

test_ds = (
    test_ds
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

# %%
for images, labels in train_ds.take(1):
    print("train images:", images.shape, images.dtype)
    print("train labels:", labels.shape, labels.numpy())
    print("pixel min:", tf.reduce_min(images).numpy())
    print("pixel max:", tf.reduce_max(images).numpy())
# Out:
# train images: (8, 512, 512, 3) <dtype: 'float32'>
# train labels: (8,) [0 3 3 3 3 0 0 3]
# pixel min: 0.32156372
# pixel max: 228.18893

# %%
for images, labels in train_ds.take(1):
    print("images shape:", images.shape)
    print("images dtype:", images.dtype)
    print("labels shape:", labels.shape)
    print("labels example:", labels.numpy()[:10])
    print("pixel min:", tf.reduce_min(images).numpy())
    print("pixel max:", tf.reduce_max(images).numpy())

    INPUT_CHANNELS = images.shape[-1]
    PIXEL_MAX = float(tf.reduce_max(images).numpy())

print("INPUT_CHANNELS:", INPUT_CHANNELS)
print("PIXEL_MAX:", PIXEL_MAX)

if INPUT_CHANNELS != 3:
    raise ValueError(
        f"DenseNet121 ожидает 3 канала. Сейчас каналов: {INPUT_CHANNELS}. "
        "Проверьте подготовку датасета: grayscale должен быть продублирован в RGB."
    )

if "class_weight_dict" not in globals():
    raise RuntimeError("Не найдена переменная class_weight_dict.")

SCALE_0_1_TO_255 = PIXEL_MAX <= 1.5
print("SCALE_0_1_TO_255:", SCALE_0_1_TO_255)
print("class_weight_dict:")
print(class_weight_dict)
print("type:", type(class_weight_dict))
# Out:
# images shape: (8, 512, 512, 3)
# images dtype: <dtype: 'float32'>
# labels shape: (8,)
# labels example: [3 0 0 3 3 2 3 0]
# pixel min: 0.0
# pixel max: 237.58763
# INPUT_CHANNELS: 3
# PIXEL_MAX: 237.58763122558594
# SCALE_0_1_TO_255: False
# class_weight_dict:
# {0: 0.7686170212765957, 1: 1.6055555555555556, 2: 2.408333333333333, 3: 0.6020833333333333}
# type: <class 'dict'>

# %%
from pathlib import Path
from datetime import datetime
import json

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    roc_auc_score,
    roc_curve,
    auc
)
from sklearn.preprocessing import label_binarize

# %%
@tf.keras.utils.register_keras_serializable(package="custom")
class SparseMacroF1(tf.keras.metrics.Metric):
    def __init__(self, num_classes, name="macro_f1", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = int(num_classes)

        self.cm = self.add_weight(
            name="confusion_matrix",
            shape=(self.num_classes, self.num_classes),
            initializer="zeros",
            dtype=tf.float32
        )

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.reshape(tf.cast(y_true, tf.int32), [-1])
        y_pred = tf.argmax(y_pred, axis=-1, output_type=tf.int32)

        cm_batch = tf.math.confusion_matrix(
            y_true,
            y_pred,
            num_classes=self.num_classes,
            dtype=tf.float32
        )

        self.cm.assign_add(cm_batch)

    def result(self):
        tp = tf.linalg.diag_part(self.cm)
        fp = tf.reduce_sum(self.cm, axis=0) - tp
        fn = tf.reduce_sum(self.cm, axis=1) - tp

        precision = tf.math.divide_no_nan(tp, tp + fp)
        recall = tf.math.divide_no_nan(tp, tp + fn)

        f1 = tf.math.divide_no_nan(
            2.0 * precision * recall,
            precision + recall
        )

        return tf.reduce_mean(f1)

    def reset_state(self):
        self.cm.assign(tf.zeros_like(self.cm))

    def get_config(self):
        config = super().get_config()
        config.update({"num_classes": self.num_classes})
        return config
    
@tf.keras.utils.register_keras_serializable(package="custom")
class SparseMacroAUC(tf.keras.metrics.Metric):
    def __init__(self, num_classes, name="macro_auc", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = int(num_classes)

        self.auc = tf.keras.metrics.AUC(
            curve="ROC",
            multi_label=True,
            num_labels=self.num_classes,
            name=f"{name}_inner"
        )

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.reshape(tf.cast(y_true, tf.int32), [-1])
        y_true = tf.one_hot(y_true, depth=self.num_classes)

        self.auc.update_state(
            y_true,
            y_pred,
            sample_weight=sample_weight
        )

    def result(self):
        return self.auc.result()

    def reset_state(self):
        self.auc.reset_state()

    def get_config(self):
        config = super().get_config()
        config.update({"num_classes": self.num_classes})
        return config

@tf.keras.utils.register_keras_serializable(package="custom")
class SparseMacroPrecision(tf.keras.metrics.Metric):
    def __init__(self, num_classes, name="macro_precision", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = int(num_classes)

        self.cm = self.add_weight(
            name="confusion_matrix",
            shape=(self.num_classes, self.num_classes),
            initializer="zeros",
            dtype=tf.float32
        )

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.reshape(tf.cast(y_true, tf.int32), [-1])
        y_pred = tf.argmax(y_pred, axis=-1, output_type=tf.int32)

        cm_batch = tf.math.confusion_matrix(
            y_true,
            y_pred,
            num_classes=self.num_classes,
            dtype=tf.float32
        )

        self.cm.assign_add(cm_batch)

    def result(self):
        tp = tf.linalg.diag_part(self.cm)
        fp = tf.reduce_sum(self.cm, axis=0) - tp

        precision = tf.math.divide_no_nan(tp, tp + fp)

        return tf.reduce_mean(precision)

    def reset_state(self):
        self.cm.assign(tf.zeros_like(self.cm))

    def get_config(self):
        config = super().get_config()
        config.update({"num_classes": self.num_classes})
        return config
    
@tf.keras.utils.register_keras_serializable(package="custom")
class SparseMacroRecall(tf.keras.metrics.Metric):
    def __init__(self, num_classes, name="macro_recall", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = int(num_classes)

        self.cm = self.add_weight(
            name="confusion_matrix",
            shape=(self.num_classes, self.num_classes),
            initializer="zeros",
            dtype=tf.float32
        )

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.reshape(tf.cast(y_true, tf.int32), [-1])
        y_pred = tf.argmax(y_pred, axis=-1, output_type=tf.int32)

        cm_batch = tf.math.confusion_matrix(
            y_true,
            y_pred,
            num_classes=self.num_classes,
            dtype=tf.float32
        )

        self.cm.assign_add(cm_batch)

    def result(self):
        tp = tf.linalg.diag_part(self.cm)
        fn = tf.reduce_sum(self.cm, axis=1) - tp

        recall = tf.math.divide_no_nan(tp, tp + fn)

        return tf.reduce_mean(recall)

    def reset_state(self):
        self.cm.assign(tf.zeros_like(self.cm))

    def get_config(self):
        config = super().get_config()
        config.update({"num_classes": self.num_classes})
        return config

# %%
@tf.keras.utils.register_keras_serializable(package="custom")
class InceptionV3Preprocess(tf.keras.layers.Layer):
    def __init__(self, scale_0_1_to_255=False, **kwargs):
        super().__init__(**kwargs)
        self.scale_0_1_to_255 = bool(scale_0_1_to_255)

    def call(self, inputs):
        x = tf.cast(inputs, tf.float32)

        # Если датасет отдаёт 0..1, приводим к 0..255,
        # потому что inception_v3.preprocess_input ожидает вход в 0..255.
        if self.scale_0_1_to_255:
            x = x * 255.0

        x = tf.keras.applications.inception_v3.preprocess_input(x)

        return x

    def get_config(self):
        config = super().get_config()
        config.update({
            "scale_0_1_to_255": self.scale_0_1_to_255
        })
        return config

# %%
tf.keras.backend.clear_session()

from tensorflow.keras import layers, Model, regularizers

inputs = tf.keras.Input(
    shape=(MODEL_SIZE, MODEL_SIZE, 3),
    name="input_image"
)

x = InceptionV3Preprocess(
    scale_0_1_to_255=SCALE_0_1_TO_255,
    name="inceptionv3_preprocess"
)(inputs)

base = tf.keras.applications.InceptionV3(
    include_top=False,
    weights="imagenet",
    input_shape=(MODEL_SIZE, MODEL_SIZE, 3)
)

base.trainable = False

features = base(x, training=False)

gap = layers.GlobalAveragePooling2D(name="global_avg_pool")(features)
gmp = layers.GlobalMaxPooling2D(name="global_max_pool")(features)

x = layers.Concatenate(name="concat_avg_max_pool")([gap, gmp])

x = layers.LayerNormalization(
    epsilon=1e-6,
    name="head_layer_norm"
)(x)

x = layers.Dropout(
    0.40,
    name="dropout_1"
)(x)

x = layers.Dense(
    256,
    activation="swish",
    kernel_regularizer=regularizers.l2(1e-4),
    name="dense_head"
)(x)

x = layers.Dropout(
    0.30,
    name="dropout_2"
)(x)

outputs = layers.Dense(
    NUM_CLASSES,
    activation="softmax",
    kernel_regularizer=regularizers.l2(1e-4),
    name="classifier"
)(x)

model = Model(
    inputs=inputs,
    outputs=outputs,
    name="inceptionv3_hep2_classifier_precision_recall"
)

model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\Glush\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 241s 3us/step
# Model: "inceptionv3_hep2_classifier_precision_recall"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_image         │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inceptionv3_prepro… │ (None, 512, 512,  │          0 │ input_image[0][0] │
# │ (InceptionV3Prepro… │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_v3        │ (None, 14, 14,    │ 21,802,784 │ inceptionv3_prep… │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_avg_pool     │ (None, 2048)      │          0 │ inception_v3[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pool     │ (None, 2048)      │          0 │ inception_v3[0][… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat_avg_max_pool │ (None, 4096)      │          0 │ global_avg_pool[… │
# │ (Concatenate)       │                   │            │ global_max_pool[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_layer_norm     │ (None, 4096)      │      8,192 │ concat_avg_max_p… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 4096)      │          0 │ head_layer_norm[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_head (Dense)  │ (None, 256)       │  1,048,832 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ dense_head[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier (Dense)  │ (None, 4)         │      1,028 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 22,860,836 (87.21 MB)
#  Trainable params: 1,058,052 (4.04 MB)
#  Non-trainable params: 21,802,784 (83.17 MB)

# %%
stage1_metrics = [
    tf.keras.metrics.SparseCategoricalAccuracy(name="acc"),
    tf.keras.metrics.SparseTopKCategoricalAccuracy(k=2, name="top2_acc"),
    SparseMacroPrecision(num_classes=NUM_CLASSES, name="macro_precision"),
    SparseMacroRecall(num_classes=NUM_CLASSES, name="macro_recall"),
    SparseMacroF1(num_classes=NUM_CLASSES, name="macro_f1"),
    SparseMacroAUC(num_classes=NUM_CLASSES, name="macro_auc"),
]
try:
    optimizer_stage1 = tf.keras.optimizers.AdamW(
        learning_rate=2e-4,
        weight_decay=1e-4
    )
except AttributeError:
    optimizer_stage1 = tf.keras.optimizers.Adam(
        learning_rate=2e-4
    )

try:
    optimizer_stage1 = tf.keras.optimizers.AdamW(
        learning_rate=3e-4,
        weight_decay=1e-4
    )
except AttributeError:
    optimizer_stage1 = tf.keras.optimizers.Adam(
        learning_rate=3e-4
    )

model.compile(
    optimizer=optimizer_stage1,
    loss="sparse_categorical_crossentropy",
    metrics=stage1_metrics
)

# %%
stage1_weights_path = CHECKPOINT_DIR / "best_stage1.weights.h5"

callbacks_stage1 = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=str(stage1_weights_path),
        monitor="val_macro_f1",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
        verbose=1
    ),

    tf.keras.callbacks.EarlyStopping(
        monitor="val_macro_f1",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),

    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        mode="min",
        factor=0.3,
        patience=3,
        min_lr=1e-6,
        verbose=1
    ),

    tf.keras.callbacks.CSVLogger(
        filename=str(REPORTS_DIR / "stage1_training_log.csv")
    )
]

# %%
history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    class_weight=class_weight_dict,
    callbacks=callbacks_stage1
)
# Out:
# Epoch 1/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.4387 - loss: 2.0012 - macro_auc: 0.6820 - macro_f1: 0.3828 - macro_precision: 0.3989 - macro_recall: 0.3858 - top2_acc: 0.6884
# Epoch 1: val_macro_f1 improved from None to 0.66673, saving model to experiments\InceprionV3_20260419_233606\checkpoints\best_stage1.weights.h5
#
# Epoch 1: finished saving model to experiments\InceprionV3_20260419_233606\checkpoints\best_stage1.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - acc: 0.5779 - loss: 1.4719 - macro_auc: 0.7945 - macro_f1: 0.4999 - macro_precision: 0.5108 - macro_recall: 0.5082 - top2_acc: 0.8028 - val_acc: 0.8065 - val_loss: 0.5026 - val_macro_auc: 0.9578 - val_macro_f1: 0.6667 - val_macro_precision: 0.8230 - val_macro_recall: 0.6727 - val_top2_acc: 0.9355 - learning_rate: 3.0000e-04
# Epoch 2/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.7576 - loss: 0.9089 - macro_auc: 0.9118 - macro_f1: 0.6799 - macro_precision: 0.6813 - macro_recall: 0.6913 - top2_acc: 0.9295
# Epoch 2: val_macro_f1 did not improve from 0.66673
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - acc: 0.7457 - loss: 0.8864 - macro_auc: 0.9109 - macro_f1: 0.6623 - macro_precision: 0.6614 - macro_recall: 0.6773 - top2_acc: 0.9170 - val_acc: 0.8387 - val_loss: 0.4950 - val_macro_auc: 0.9601 - val_macro_f1: 0.6353 - val_macro_precision: 0.6008 - val_macro_recall: 0.6855 - val_top2_acc: 0.9355 - learning_rate: 3.0000e-04
# Epoch 3/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.7879 - loss: 0.7017 - macro_auc: 0.9445 - macro_f1: 0.7044 - macro_precision: 0.7128 - macro_recall: 0.7113 - top2_acc: 0.9503
# Epoch 3: val_macro_f1 improved from 0.66673 to 0.69828, saving model to experiments\InceprionV3_20260419_233606\checkpoints\best_stage1.weights.h5
#
# Epoch 3: finished saving model to experiments\InceprionV3_20260419_233606\checkpoints\best_stage1.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - acc: 0.8080 - loss: 0.6342 - macro_auc: 0.9480 - macro_f1: 0.7254 - macro_precision: 0.7225 - macro_recall: 0.7339 - top2_acc: 0.9550 - val_acc: 0.7984 - val_loss: 0.5299 - val_macro_auc: 0.9598 - val_macro_f1: 0.6983 - val_macro_precision: 0.8136 - val_macro_recall: 0.6786 - val_top2_acc: 0.9677 - learning_rate: 3.0000e-04
# Epoch 4/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.8340 - loss: 0.5815 - macro_auc: 0.9576 - macro_f1: 0.7451 - macro_precision: 0.7452 - macro_recall: 0.7538 - top2_acc: 0.9649
# Epoch 4: val_macro_f1 did not improve from 0.69828
# 73/73 ━━━━━━━━━━━━━━━━━━━━
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - acc: 0.8806 - loss: 0.4740 - macro_auc: 0.9726 - macro_f1: 0.8062 - macro_precision: 0.8023 - macro_recall: 0.8120 - top2_acc: 0.9827 - val_acc: 0.8790 - val_loss: 0.3912 - val_macro_auc: 0.9785 - val_macro_f1: 0.7635 - val_macro_precision: 0.8919 - val_macro_recall: 0.7764 - val_top2_acc: 1.0000 - learning_rate: 9.0000e-05
# Epoch 14/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.8864 - loss: 0.4526 - macro_auc: 0.9754 - macro_f1: 0.8272 - macro_precision: 0.8249 - macro_recall: 0.8328 - top2_acc: 0.9844
# Epoch 14: val_macro_f1 did not improve from 0.79814
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - acc: 0.8824 - loss: 0.4342 - macro_auc: 0.9763 - macro_f1: 0.8070 - macro_precision: 0.8054 - macro_recall: 0.8114 - top2_acc: 0.9931 - val_acc: 0.8790 - val_loss: 0.4201 - val_macro_auc: 0.9737 - val_macro_f1: 0.7859 - val_macro_precision: 0.8938 - val_macro_recall: 0.7894 - val_top2_acc: 1.0000 - learning_rate: 9.0000e-05
# Epoch 15/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9052 - loss: 0.3904 - macro_auc: 0.9726 - macro_f1: 0.8252 - macro_precision: 0.8335 - macro_recall: 0.8287 - top2_acc: 0.9855
# Epoch 15: val_macro_f1 did not improve from 0.79814
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - acc: 0.8806 - loss: 0.4378 - macro_auc: 0.9775 - macro_f1: 0.8055 - macro_precision: 0.8026 - macro_recall: 0.8095 - top2_acc: 0.9775 - val_acc: 0.8790 - val_loss: 0.4432 - val_macro_auc: 0.9702 - val_macro_f1: 0.7859 - val_macro_precision: 0.8938 - val_macro_recall: 0.7894 - val_top2_acc: 1.0000 - learning_rate: 2.7000e-05
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.

# %%
model.load_weights(stage1_weights_path)

base.trainable = True

# Сначала замораживаем весь backbone
for layer in base.layers:
    layer.trainable = False

# Размораживаем верхние Inception-блоки начиная с mixed7
set_trainable = False

for layer in base.layers:
    if layer.name == "mixed7":
        set_trainable = True

    if set_trainable:
        layer.trainable = True

# BatchNorm оставляем замороженными
for layer in base.layers:
    if isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = False

trainable_layers = sum(layer.trainable for layer in base.layers)

print("Backbone layers:", len(base.layers))
print("Trainable backbone layers:", trainable_layers)

for layer in base.layers:
    if layer.trainable:
        print("trainable:", layer.name)
# Out:
# Backbone layers: 311
# Trainable backbone layers: 59
# trainable: mixed7
# trainable: conv2d_72
# trainable: activation_72
# trainable: conv2d_73
# trainable: activation_73
# trainable: conv2d_70
# trainable: conv2d_74
# trainable: activation_70
# trainable: activation_74
# trainable: conv2d_71
# trainable: conv2d_75
# trainable: activation_71
# trainable: activation_75
# trainable: max_pooling2d_3
# trainable: mixed8
# trainable: conv2d_80
# trainable: activation_80
# trainable: conv2d_77
# trainable: conv2d_81
# trainable: activation_77
# trainable: activation_81
# trainable: conv2d_78
# trainable: conv2d_79
# trainable: conv2d_82
# trainable: conv2d_83
# trainable: average_pooling2d_7
# trainable: conv2d_76
# trainable: conv2d_84
# trainable: activation_78
# trainable: activation_79
# trainable: activation_82
# trainable: activation_83
# trainable: activation_76
# trainable: mixed9_0
# trainable: concatenate
# trainable: activation_84
# trainable: mixed9
# trainable: conv2d_89
# trainable: activation_89
# trainable: conv2d_86
# trainable: conv2d_90
# trainable: activation_86
# trainable: activation_90
# trainable: conv2d_87
# trainable: conv2d_88
# trainable: conv2d_91
# trainable: conv2d_92
# trainable: average_pooling2d_8
# trainable: conv2d_85
# trainable: conv2d_93
# trainable: activation_87
# trainable: activation_88
# trainable: activation_91
# trainable: activation_92
# trainable: activation_85
# trainable: mixed9_1
# trainable: concatenate_1
# trainable: activation_93
# trainable: mixed10

# %%
stage2_metrics = [
    tf.keras.metrics.SparseCategoricalAccuracy(name="acc"),
    tf.keras.metrics.SparseTopKCategoricalAccuracy(k=2, name="top2_acc"),
    SparseMacroPrecision(num_classes=NUM_CLASSES, name="macro_precision"),
    SparseMacroRecall(num_classes=NUM_CLASSES, name="macro_recall"),
    SparseMacroF1(num_classes=NUM_CLASSES, name="macro_f1"),
    SparseMacroAUC(num_classes=NUM_CLASSES, name="macro_auc"),
]
try:
    optimizer_stage2 = tf.keras.optimizers.AdamW(
        learning_rate=5e-6,
        weight_decay=1e-5
    )
except AttributeError:
    optimizer_stage2 = tf.keras.optimizers.Adam(
        learning_rate=5e-6
    )

model.compile(
    optimizer=optimizer_stage2,
    loss="sparse_categorical_crossentropy",
    metrics=stage2_metrics
)

# %%
stage2_weights_path = CHECKPOINT_DIR / "best_stage2.weights.h5"

callbacks_stage2 = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=str(stage2_weights_path),
        monitor="val_macro_f1",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
        verbose=1
    ),

    tf.keras.callbacks.EarlyStopping(
        monitor="val_macro_f1",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),

    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        mode="min",
        factor=0.3,
        patience=3,
        min_lr=1e-7,
        verbose=1
    ),

    tf.keras.callbacks.CSVLogger(
        filename=str(REPORTS_DIR / "stage2_training_log.csv")
    )
]

# %%
history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    class_weight=class_weight_dict,
    callbacks=callbacks_stage2
)
# Out:
# Epoch 1/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.8282 - loss: 0.5629 - macro_auc: 0.9568 - macro_f1: 0.7324 - macro_precision: 0.7383 - macro_recall: 0.7504 - top2_acc: 0.9811
# Epoch 1: val_macro_f1 improved from None to 0.76744, saving model to experiments\InceprionV3_20260419_233606\checkpoints\best_stage2.weights.h5
#
# Epoch 1: finished saving model to experiments\InceprionV3_20260419_233606\checkpoints\best_stage2.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - acc: 0.8927 - loss: 0.4254 - macro_auc: 0.9779 - macro_f1: 0.8256 - macro_precision: 0.8239 - macro_recall: 0.8338 - top2_acc: 0.9879 - val_acc: 0.8790 - val_loss: 0.4309 - val_macro_auc: 0.9738 - val_macro_f1: 0.8116 - val_macro_precision: 0.8617 - val_macro_recall: 0.8016 - val_top2_acc: 0.9919 - learning_rate: 5.0000e-06
# Epoch 6/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.8974 - loss: 0.3831 - macro_auc: 0.9736 - macro_f1: 0.8156 - macro_precision: 0.8165 - macro_recall: 0.8335 - top2_acc: 0.9909
# Epoch 6: val_macro_f1 did not improve from 0.81164
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-06.
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - acc: 0.8927 - loss: 0.4076 - macro_auc: 0.9804 - macro_f1: 0.8326 - macro_precision: 0.8299 - macro_recall: 0.8429 - top2_acc: 0.9879 - val_acc: 0.8710 - val_loss: 0.3875 - val_macro_auc: 0.9788 - val_macro_f1: 0.7973 - val_macro_precision: 0.8318 - val_macro_recall: 0.7884 - val_top2_acc: 1.0000 - learning_rate: 5.0000e-06
# Epoch 7/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.8974 - loss: 0.3775 - macro_auc: 0.9799 - macro_f1: 0.8403 - macro_precision: 0.8349 - macro_recall: 0.8530 - top2_acc: 0.9793
# Epoch 7: val_macro_f1 improved from 0.81164 to 0.82305, saving model to experiments\InceprionV3_20260419_233606\checkpoints\best_stage2.weights.h5
#
# Epoch 7: finished saving model to experiments\InceprionV3_20260419_233606\checkpoints\best_stage2.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - acc: 0.9048 - loss: 0.3562 - macro_auc: 0.9865 - macro_f1: 0.8576 - macro_precision: 0.8507 - macro_recall: 0.8692 - top2_acc: 0.9844 - val_acc: 0.8952 - val_loss: 0.3769 - val_macro_auc: 0.9810 - val_macro_f1: 0.8230 - val_macro_precision: 0.8694 - val_macro_recall: 0.8141 - val_top2_acc: 1.0000 - learning_rate: 1.5000e-06
# Epoch 8/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.8963 - loss: 0.3758 - macro_auc: 0.9800 - macro_f1: 0.8388 - macro_precision: 0.8368 - macro_recall: 0.8446 - top2_acc: 0.9923
# Epoch 8: val_macro_f1 did not improve from 0.82305
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - acc: 0.8997 - loss: 0.3765 - macro_auc: 0.9823 - macro_f1: 0.8344 - macro_precision: 0.8305 - macro_recall: 0.8398 - top2_acc: 0.9913 - val_acc: 0.8952 - val_loss: 0.3695 - val_macro_auc: 0.9825 - val_macro_f1: 0.8230 - val_macro_precision: 0.8694 - val_macro_recall: 0.8141 - val_top2_acc: 1.0000 - learning_rate: 1.5000e-06
# Epoch 9/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9328 - loss: 0.3161 - macro_auc: 0.9857 - macro_f1: 0.8765 - macro_precision: 0.8765 - macro_recall: 0.8836 - top2_acc: 0.9916
# Epoch 9: val_macro_f1 improved from 0.82305 to 0.83781, saving model to experiments\InceprionV3_20260419_233606\checkpoints\best_stage2.weights.h5
#
# Epoch 9: finished saving model to experiments\InceprionV3_20260419_233606\checkpoints\best_stage2.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - acc: 0.9239 - loss: 0.3317 - macro_auc: 0.9887 - macro_f1: 0.8648 - macro_precision: 0.8646 - macro_recall: 0.8734 - top2_acc: 0.9948 - val_acc: 0.9032 - val_loss: 0.3838 - val_macro_auc: 0.9817 - val_macro_f1: 0.8378 - val_macro_precision: 0.9081 - val_macro_recall: 0.8272 - val_top2_acc: 1.0000 - learning_rate: 1.5000e-06
# Epoch 10/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9223 - loss: 0.3211 - macro_auc: 0.9854 - macro_f1: 0.8659 - macro_precision: 0.8645 - macro_recall: 0.8730 - top2_acc: 0.9913
# Epoch 10: val_macro_f1 did not improve from 0.83781
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - acc: 0.9135 - loss: 0.3650 - macro_auc: 0.9849 - macro_f1: 0.8604 - macro_precision: 0.8580 - macro_recall: 0.8659 - top2_acc: 0.9931 - val_acc: 0.8952 - val_loss: 0.3663 - val_macro_auc: 0.9831 - val_macro_f1: 0.8230 - val_macro_precision: 0.8694 - val_macro_recall: 0.8141 - val_top2_acc: 1.0000 - learning_rate: 1.5000e-06
# Epoch 11/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9278 - loss: 0.3078 - macro_auc: 0.9880 - macro_f1: 0.8640 - macro_precision: 0.8635 - macro_recall: 0.8720 - top2_acc: 0.9978
# Epoch 11: val_macro_f1 improved from 0.83781 to 0.83874, saving model to experiments\InceprionV3_20260419_233606\checkpoints\best_stage2.weights.h5
#
# Epoch 11: finished saving model to experiments\InceprionV3_20260419_233606\checkpoints\best_stage2.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - acc: 0.9291 - loss: 0.3192 - macro_auc: 0.9893 - macro_f1: 0.8833 - macro_precision: 0.8799 - macro_recall: 0.8869 - top2_acc: 0.9983 - val_acc: 0.8952 - val_loss: 0.3753 - val_macro_auc: 0.9796 - val_macro_f1: 0.8387 - val_macro_precision: 0.8777 - val_macro_recall: 0.8270 - val_top2_acc: 1.0000 - learning_rate: 1.5000e-06
# Epoch 12/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9382 - loss: 0.3149 - macro_auc: 0.9860 - macro_f1: 0.9050 - macro_precision: 0.9088 - macro_recall: 0.9119 - top2_acc: 0.9998
# Epoch 12: val_macro_f1 did not improve from 0.83874
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - acc: 0.9291 - loss: 0.3375 - macro_auc: 0.9863 - macro_f1: 0.8868 - macro_precision: 0.8856 - macro_recall: 0.8994 - top2_acc: 0.9983 - val_acc: 0.8952 - val_loss: 0.3868 - val_macro_auc: 0.9783 - val_macro_f1: 0.8230 - val_macro_precision: 0.8694 - val_macro_recall: 0.8141 - val_top2_acc: 1.0000 - learning_rate: 1.5000e-06
# Epoch 13/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9039 - loss: 0.3627 - macro_auc: 0.9764 - macro_f1: 0.8425 - macro_precision: 0.8404 - macro_recall: 0.8520 - top2_acc: 0.9998
# Epoch 13: val_macro_f1 improved from 0.83874 to 0.84659, saving model to experiments\InceprionV3_20260419_233606\checkpoints\best_stage2.weights.h5
#
# Epoch 13: finished saving model to experiments\InceprionV3_20260419_233606\checkpoints\best_stage2.weights.h5
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.4999998181083353e-07.
# 73/73 ━━━━━━━━━━━━━━━━━━━━
50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9103 - loss: 0.3938 - macro_auc: 0.9832 - macro_f1: 0.8637 - macro_precision: 0.8626 - macro_recall: 0.8686 - top2_acc: 0.9938
# Epoch 18: val_macro_f1 did not improve from 0.84659
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - acc: 0.9187 - loss: 0.3518 - macro_auc: 0.9856 - macro_f1: 0.8645 - macro_precision: 0.8609 - macro_recall: 0.8685 - top2_acc: 0.9965 - val_acc: 0.8952 - val_loss: 0.3949 - val_macro_auc: 0.9795 - val_macro_f1: 0.8230 - val_macro_precision: 0.8694 - val_macro_recall: 0.8141 - val_top2_acc: 1.0000 - learning_rate: 1.3500e-07
# Epoch 19/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9087 - loss: 0.4008 - macro_auc: 0.9781 - macro_f1: 0.8478 - macro_precision: 0.8496 - macro_recall: 0.8491 - top2_acc: 0.9982
# Epoch 19: val_macro_f1 did not improve from 0.84659
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1e-07.
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - acc: 0.9204 - loss: 0.3454 - macro_auc: 0.9873 - macro_f1: 0.8686 - macro_precision: 0.8675 - macro_recall: 0.8721 - top2_acc: 0.9948 - val_acc: 0.9032 - val_loss: 0.3931 - val_macro_auc: 0.9797 - val_macro_f1: 0.8321 - val_macro_precision: 0.8764 - val_macro_recall: 0.8272 - val_top2_acc: 1.0000 - learning_rate: 1.3500e-07
# Epoch 20/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9075 - loss: 0.3589 - macro_auc: 0.9841 - macro_f1: 0.8402 - macro_precision: 0.8350 - macro_recall: 0.8572 - top2_acc: 0.9908
# Epoch 20: val_macro_f1 did not improve from 0.84659
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - acc: 0.9187 - loss: 0.3347 - macro_auc: 0.9862 - macro_f1: 0.8685 - macro_precision: 0.8622 - macro_recall: 0.8843 - top2_acc: 0.9931 - val_acc: 0.9032 - val_loss: 0.3933 - val_macro_auc: 0.9795 - val_macro_f1: 0.8321 - val_macro_precision: 0.8764 - val_macro_recall: 0.8272 - val_top2_acc: 1.0000 - learning_rate: 1.0000e-07
# Epoch 21/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9342 - loss: 0.3593 - macro_auc: 0.9727 - macro_f1: 0.8841 - macro_precision: 0.8858 - macro_recall: 0.8849 - top2_acc: 0.9968
# Epoch 21: val_macro_f1 did not improve from 0.84659
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - acc: 0.9239 - loss: 0.3495 - macro_auc: 0.9860 - macro_f1: 0.8837 - macro_precision: 0.8796 - macro_recall: 0.8885 - top2_acc: 0.9931 - val_acc: 0.8952 - val_loss: 0.3950 - val_macro_auc: 0.9796 - val_macro_f1: 0.8230 - val_macro_precision: 0.8694 - val_macro_recall: 0.8141 - val_top2_acc: 1.0000 - learning_rate: 1.0000e-07
# Epoch 22/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9004 - loss: 0.3677 - macro_auc: 0.9786 - macro_f1: 0.8177 - macro_precision: 0.8144 - macro_recall: 0.8242 - top2_acc: 1.0000
# Epoch 22: val_macro_f1 did not improve from 0.84659
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - acc: 0.8979 - loss: 0.3690 - macro_auc: 0.9832 - macro_f1: 0.8361 - macro_precision: 0.8305 - macro_recall: 0.8431 - top2_acc: 1.0000 - val_acc: 0.8952 - val_loss: 0.3937 - val_macro_auc: 0.9794 - val_macro_f1: 0.8230 - val_macro_precision: 0.8694 - val_macro_recall: 0.8141 - val_top2_acc: 1.0000 - learning_rate: 1.0000e-07
# Epoch 23/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.9283 - loss: 0.3252 - macro_auc: 0.9895 - macro_f1: 0.8878 - macro_precision: 0.8832 - macro_recall: 0.8982 - top2_acc: 0.9944
# Epoch 23: val_macro_f1 did not improve from 0.84659
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - acc: 0.9325 - loss: 0.3223 - macro_auc: 0.9897 - macro_f1: 0.8914 - macro_precision: 0.8859 - macro_recall: 0.8991 - top2_acc: 0.9948 - val_acc: 0.8952 - val_loss: 0.3945 - val_macro_auc: 0.9793 - val_macro_f1: 0.8230 - val_macro_precision: 0.8694 - val_macro_recall: 0.8141 - val_top2_acc: 1.0000 - learning_rate: 1.0000e-07
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.

# %%
history_all = {}

for h in [history1, history2]:
    for key, values in h.history.items():
        if key not in history_all:
            history_all[key] = []
        history_all[key].extend(values)

stage1_epochs = len(history1.history["loss"])
total_epochs = len(history_all["loss"])

history_df = pd.DataFrame(history_all)
history_df.insert(0, "epoch", np.arange(1, total_epochs + 1))

history_df["stage"] = [
    "stage1" if i < stage1_epochs else "stage2"
    for i in range(total_epochs)
]

history_csv_path = REPORTS_DIR / "combined_training_history.csv"
history_df.to_csv(history_csv_path, index=False, encoding="utf-8-sig")

print("Saved:", history_csv_path)
history_df.head()
# Out:
# Saved: experiments\InceprionV3_20260419_233606\reports\combined_training_history.csv
#    epoch       acc      loss  macro_auc  macro_f1  macro_precision  \
# 0      1  0.577855  1.471892   0.794516  0.499857         0.510846
# 1      2  0.745675  0.886428   0.910925  0.662315         0.661360
# 2      3  0.807958  0.634163   0.947954  0.725387         0.722455
# 3      4  0.835640  0.572840   0.958413  0.759954         0.754508
# 4      5  0.811419  0.642416   0.948832  0.726050         0.723022
#
#    macro_recall  top2_acc   val_acc  val_loss  val_macro_auc  val_macro_f1  \
# 0      0.508208  0.802768  0.806452  0.502646       0.957831      0.666728
# 1      0.677327  0.916955  0.838710  0.494998       0.960095      0.635256
# 2      0.733895  0.955017  0.798387  0.529853       0.959761      0.698281
# 3      0.768262  0.965398  0.798387  0.498534       0.972108      0.651869
# 4      0.739450  0.963668  0.862903  0.403632       0.972099      0.798143
#
#    val_macro_precision  val_macro_recall  val_top2_acc  learning_rate   stage
# 0             0.823026          0.672672      0.935484         0.0003  stage1
# 1             0.600843          0.685526      0.935484         0.0003  stage1
# 2             0.813625          0.678568      0.967742         0.0003  stage1
# 3             0.729979          0.713335      0.967742         0.0003  stage1
# 4             0.808463          0.793472      0.991935         0.0003  stage1

# %%
plt.figure(figsize=(9, 5))

plt.plot(history_all["loss"], label="train_loss")
plt.plot(history_all["val_loss"], label="val_loss")

plt.axvline(
    stage1_epochs - 0.5,
    linestyle="--",
    label="fine-tune start"
)

plt.title("InceptionV3: Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, alpha=0.3)

out_path = PLOTS_DIR / "loss_curve.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)
# Out:
# Saved: experiments\InceprionV3_20260419_233606\plots\loss_curve.png

# %%
plt.figure(figsize=(9, 5))

plt.plot(history_all["acc"], label="train_acc")
plt.plot(history_all["val_acc"], label="val_acc")

plt.axvline(
    stage1_epochs - 0.5,
    linestyle="--",
    label="fine-tune start"
)

plt.title("InceptionV3: Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True, alpha=0.3)

out_path = PLOTS_DIR / "accuracy_curve.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)
# Out:
# Saved: experiments\InceprionV3_20260419_233606\plots\accuracy_curve.png

# %%
plt.figure(figsize=(9, 5))

plt.plot(history_all["macro_precision"], label="train_macro_precision")
plt.plot(history_all["val_macro_precision"], label="val_macro_precision")

plt.axvline(
    stage1_epochs - 0.5,
    linestyle="--",
    label="fine-tune start"
)

plt.title("InceptionV3: Macro Precision")
plt.xlabel("Epoch")
plt.ylabel("Macro Precision")
plt.legend()
plt.grid(True, alpha=0.3)

out_path = PLOTS_DIR / "macro_precision_curve.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)
# Out:
# Saved: experiments\InceprionV3_20260419_233606\plots\macro_precision_curve.png

# %%
plt.figure(figsize=(9, 5))

plt.plot(history_all["macro_recall"], label="train_macro_recall")
plt.plot(history_all["val_macro_recall"], label="val_macro_recall")

plt.axvline(
    stage1_epochs - 0.5,
    linestyle="--",
    label="fine-tune start"
)

plt.title("InceptionV3: Macro Recall")
plt.xlabel("Epoch")
plt.ylabel("Macro Recall")
plt.legend()
plt.grid(True, alpha=0.3)

out_path = PLOTS_DIR / "macro_recall_curve.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)
# Out:
# Saved: experiments\InceprionV3_20260419_233606\plots\macro_recall_curve.png

# %%
plt.figure(figsize=(9, 5))

plt.plot(history_all["macro_f1"], label="train_macro_f1")
plt.plot(history_all["val_macro_f1"], label="val_macro_f1")

plt.axvline(
    stage1_epochs - 0.5,
    linestyle="--",
    label="fine-tune start"
)

plt.title("InceptionV3: Macro F1")
plt.xlabel("Epoch")
plt.ylabel("Macro F1")
plt.legend()
plt.grid(True, alpha=0.3)

out_path = PLOTS_DIR / "macro_f1_curve.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)
# Out:
# Saved: experiments\InceprionV3_20260419_233606\plots\macro_f1_curve.png

# %%
plt.figure(figsize=(9, 5))

plt.plot(history_all["macro_auc"], label="train_macro_auc")
plt.plot(history_all["val_macro_auc"], label="val_macro_auc")

plt.axvline(
    stage1_epochs - 0.5,
    linestyle="--",
    label="fine-tune start"
)

plt.title("InceptionV3: Macro ROC-AUC")
plt.xlabel("Epoch")
plt.ylabel("Macro ROC-AUC")
plt.legend()
plt.grid(True, alpha=0.3)

out_path = PLOTS_DIR / "macro_auc_curve.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)
# Out:
# Saved: experiments\InceprionV3_20260419_233606\plots\macro_auc_curve.png

# %%
test_results = model.evaluate(test_ds, return_dict=True)

print("Test results:")
for key, value in test_results.items():
    print(f"{key}: {value:.4f}")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - acc: 0.8320 - loss: 0.5048 - macro_auc: 0.9603 - macro_f1: 0.7538 - macro_precision: 0.8202 - macro_recall: 0.7457 - top2_acc: 1.0000
# Test results:
# acc: 0.8320
# loss: 0.5048
# macro_auc: 0.9603
# macro_f1: 0.7538
# macro_precision: 0.8202
# macro_recall: 0.7457
# top2_acc: 1.0000

# %%
y_true = []
y_prob = []

for images, labels in test_ds:
    probs = model.predict(images, verbose=0)

    y_true.extend(labels.numpy().tolist())
    y_prob.extend(probs.tolist())

y_true = np.array(y_true)
y_prob = np.array(y_prob)
y_pred = np.argmax(y_prob, axis=1)

print("y_true:", y_true.shape)
print("y_prob:", y_prob.shape)
print("y_pred:", y_pred.shape)
# Out:
# y_true: (125,)
# y_prob: (125, 4)
# y_pred: (125,)

# %%
report_text = classification_report(
    y_true,
    y_pred,
    target_names=CLASS_NAMES,
    digits=4,
    zero_division=0
)

print(report_text)
# Out:
#               precision    recall  f1-score   support
#
#           24     0.9688    0.7561    0.8493        41
#           48     0.6400    0.8421    0.7273        19
#           72     0.8333    0.3846    0.5263        13
#      control     0.8387    1.0000    0.9123        52
#
#     accuracy                         0.8320       125
#    macro avg     0.8202    0.7457    0.7538       125
# weighted avg     0.8506    0.8320    0.8234       125

# %%
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=CLASS_NAMES
)

fig, ax = plt.subplots(figsize=(6, 6))
disp.plot(values_format="d", ax=ax)

plt.title("DenseNet121: Confusion Matrix")
plt.grid(False)

out_path = PLOTS_DIR / "confusion_matrix.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 disp = ConfusionMatrixDisplay(
# ----> 2     confusion_matrix=cm,
#       3     display_labels=CLASS_NAMES
#       4 )
#       6 fig, ax = plt.subplots(figsize=(6, 6))
#       7 disp.plot(values_format="d", ax=ax)
#
# NameError: name 'cm' is not defined

# %%
per_class_precision, per_class_recall, per_class_f1, per_class_support = (
    precision_recall_fscore_support(
        y_true,
        y_pred,
        labels=np.arange(NUM_CLASSES),
        zero_division=0
    )
)

per_class_df = pd.DataFrame({
    "class": CLASS_NAMES,
    "precision": per_class_precision,
    "recall": per_class_recall,
    "f1": per_class_f1,
    "support": per_class_support
})

per_class_path = REPORTS_DIR / "per_class_precision_recall_f1.csv"
per_class_df.to_csv(per_class_path, index=False, encoding="utf-8-sig")

print(per_class_df)
print("Saved:", per_class_path)

# %%
per_class_precision, per_class_recall, per_class_f1, per_class_support = (
    precision_recall_fscore_support(
        y_true,
        y_pred,
        labels=np.arange(NUM_CLASSES),
        zero_division=0
    )
)

per_class_df = pd.DataFrame({
    "class": CLASS_NAMES,
    "precision": per_class_precision,
    "recall": per_class_recall,
    "f1": per_class_f1,
    "support": per_class_support
})

per_class_path = REPORTS_DIR / "per_class_precision_recall_f1.csv"
per_class_df.to_csv(per_class_path, index=False, encoding="utf-8-sig")

print(per_class_df)
print("Saved:", per_class_path)

# %%
x = np.arange(NUM_CLASSES)
width = 0.25

plt.figure(figsize=(10, 5))

plt.bar(
    x - width,
    per_class_df["precision"],
    width,
    label="Precision"
)

plt.bar(
    x,
    per_class_df["recall"],
    width,
    label="Recall"
)

plt.bar(
    x + width,
    per_class_df["f1"],
    width,
    label="F1"
)

plt.xticks(x, CLASS_NAMES)
plt.ylim(0, 1.05)

plt.title("DenseNet121: Per-class Precision / Recall / F1")
plt.xlabel("Class")
plt.ylabel("Score")
plt.legend()
plt.grid(axis="y", alpha=0.3)

out_path = PLOTS_DIR / "per_class_precision_recall_f1.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)

# %%
y_true_bin = label_binarize(
    y_true,
    classes=np.arange(NUM_CLASSES)
)

plt.figure(figsize=(8, 6))

per_class_auc = {}

for i, class_name in enumerate(CLASS_NAMES):
    fpr, tpr, _ = roc_curve(
        y_true_bin[:, i],
        y_prob[:, i]
    )

    class_auc = auc(fpr, tpr)
    per_class_auc[class_name] = float(class_auc)

    plt.plot(
        fpr,
        tpr,
        label=f"{class_name} AUC={class_auc:.3f}"
    )

plt.plot(
    [0, 1],
    [0, 1],
    linestyle="--",
    label="chance"
)

plt.title("DenseNet121: ROC Curves by Class")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(True, alpha=0.3)

out_path = PLOTS_DIR / "roc_curves_by_class.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)

for cls, value in per_class_auc.items():
    print(f"{cls:>8}: {value:.4f}")

# %%
plt.figure(figsize=(8, 6))

per_class_average_precision = {}

for i, class_name in enumerate(CLASS_NAMES):
    precision_curve, recall_curve, _ = precision_recall_curve(
        y_true_bin[:, i],
        y_prob[:, i]
    )

    avg_precision = average_precision_score(
        y_true_bin[:, i],
        y_prob[:, i]
    )

    per_class_average_precision[class_name] = float(avg_precision)

    plt.plot(
        recall_curve,
        precision_curve,
        label=f"{class_name} AP={avg_precision:.3f}"
    )

plt.title("DenseNet121: Precision-Recall Curves by Class")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.ylim(0, 1.05)
plt.xlim(0, 1.0)
plt.legend()
plt.grid(True, alpha=0.3)

out_path = PLOTS_DIR / "precision_recall_curves_by_class.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)

for cls, value in per_class_average_precision.items():
    print(f"{cls:>8}: AP={value:.4f}")
