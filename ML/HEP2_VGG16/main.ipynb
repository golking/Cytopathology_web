# %%
from pathlib import Path
from collections import Counter


from sklearn.model_selection import train_test_split

from pathlib import Path
from datetime import datetime
import json

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
    roc_curve,
    auc,
    precision_recall_fscore_support,
    precision_recall_curve,
    average_precision_score
)
from sklearn.preprocessing import label_binarize

# %%
CLASS_NAMES = ["24", "48", "72", "healthy"]
NUM_CLASSES = len(CLASS_NAMES)

MODEL_SIZE = 512
SEED = 42
FORCE_GRAYSCALE = True

tf.random.set_seed(SEED)
np.random.seed(SEED)

EXPERIMENT_ROOT = Path("experiments")
EXPERIMENT_ROOT.mkdir(exist_ok=True)

RUN_ID = f"VGG16_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
EXP_DIR = EXPERIMENT_ROOT / RUN_ID

CHECKPOINT_DIR = EXP_DIR / "checkpoints"
PLOTS_DIR = EXP_DIR / "plots"
REPORTS_DIR = EXP_DIR / "reports"

CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)
PLOTS_DIR.mkdir(parents=True, exist_ok=True)
REPORTS_DIR.mkdir(parents=True, exist_ok=True)

print("Experiment:", RUN_ID)
print("Output directory:", EXP_DIR)
# Out:
# Experiment: VGG16_20260419_185227
# Output directory: experiments\VGG16_20260419_185227

# %%
DATA_ROOT = Path(r"D:\\cells\\ML\\HEP2_png")

CLASS_NAMES = ["24", "48", "72", "control"]
CLASS_TO_IDX = {class_name: idx for idx, class_name in enumerate(CLASS_NAMES)}
IDX_TO_CLASS = {idx: class_name for class_name, idx in CLASS_TO_IDX.items()}

IMG_SIZE = 512
BATCH_SIZE = 8
SEED = 42

# Если RAM мало, можно поставить False
USE_CACHE = True

AUTOTUNE = tf.data.AUTOTUNE

tf.random.set_seed(SEED)
np.random.seed(SEED)

print(CLASS_TO_IDX)
# Out:
# {'24': 0, '48': 1, '72': 2, 'control': 3}

# %%
rows = []

for class_name in CLASS_NAMES:
    class_dir = DATA_ROOT / class_name

    if not class_dir.exists():
        raise FileNotFoundError(f"Не найдена папка класса: {class_dir}")

    image_paths = sorted(class_dir.glob("*.png"))

    if len(image_paths) == 0:
        raise RuntimeError(f"В папке {class_dir} нет PNG-изображений")

    for path in image_paths:
        rows.append({
            "path": str(path),
            "class": class_name,
            "label": CLASS_TO_IDX[class_name]
        })

df = pd.DataFrame(rows)

print("Всего изображений:", len(df))
df.head()
# Out:
# Всего изображений: 827
#                                                 path class  label
# 0  D:\cells\ML\HEP2_png\24\TUC-20251219092727377.png    24      0
# 1  D:\cells\ML\HEP2_png\24\TUC-20251219092733486.png    24      0
# 2  D:\cells\ML\HEP2_png\24\TUC-20251219092737240.png    24      0
# 3  D:\cells\ML\HEP2_png\24\TUC-20251219092741404.png    24      0
# 4  D:\cells\ML\HEP2_png\24\TUC-20251219092745351.png    24      0

# %%
class_counts = (
    df["class"]
    .value_counts()
    .reindex(CLASS_NAMES)
    .fillna(0)
    .astype(int)
)

print(class_counts)
# Out:
# class
# 24         269
# 48         128
# 72          86
# control    344
# Name: count, dtype: int32

# %%
df_train, df_temp = train_test_split(
    df,
    test_size=0.30,
    random_state=SEED,
    stratify=df["label"]
)

df_val, df_test = train_test_split(
    df_temp,
    test_size=0.50,
    random_state=SEED,
    stratify=df_temp["label"]
)

df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

print("train:", len(df_train))
print("val:  ", len(df_val))
print("test: ", len(df_test))
# Out:
# train: 578
# val:   124
# test:  125

# %%
def show_split_distribution(name, split_df):
    counts = (
        split_df["class"]
        .value_counts()
        .reindex(CLASS_NAMES)
        .fillna(0)
        .astype(int)
    )

    print(f"\n{name}")
    print(counts)
    return counts


train_counts = show_split_distribution("TRAIN", df_train)
val_counts = show_split_distribution("VAL", df_val)
test_counts = show_split_distribution("TEST", df_test)
# Out:
# TRAIN
# class
# 24         188
# 48          90
# 72          60
# control    240
# Name: count, dtype: int32
#
# VAL
# class
# 24         40
# 48         19
# 72         13
# control    52
# Name: count, dtype: int32
#
# TEST
# class
# 24         41
# 48         19
# 72         13
# control    52
# Name: count, dtype: int32

# %%
n_train = int(train_counts.sum())
n_classes = len(CLASS_NAMES)

class_weight_dict = {}

for class_name in CLASS_NAMES:
    class_idx = CLASS_TO_IDX[class_name]
    count = int(train_counts[class_name])

    if count == 0:
        raise RuntimeError(f"В train нет изображений класса {class_name}")

    weight = n_train / (n_classes * count)
    class_weight_dict[int(class_idx)] = float(weight)

print("class_weight_dict:")
for idx, weight in class_weight_dict.items():
    print(f"{idx} ({IDX_TO_CLASS[idx]}): {weight:.4f}")
# Out:
# class_weight_dict:
# 0 (24): 0.7686
# 1 (48): 1.6056
# 2 (72): 2.4083
# 3 (control): 0.6021

# %%
def load_image_grayscale_rgb(path, label):
    image_bytes = tf.io.read_file(path)

    image = tf.io.decode_png(
        image_bytes,
        channels=3
    )

    image = tf.cast(image, tf.float32)

    # RGB -> grayscale -> RGB
    # На выходе 3 канала, но изображение остаётся чёрно-белым.
    image = tf.image.rgb_to_grayscale(image)
    image = tf.image.grayscale_to_rgb(image)

    image = tf.image.resize(
        image,
        size=(IMG_SIZE, IMG_SIZE),
        method="bilinear"
    )

    label = tf.cast(label, tf.int32)

    return image, label

# %%
augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.05),
    tf.keras.layers.RandomZoom(0.10),
    tf.keras.layers.RandomTranslation(0.05, 0.05),
    tf.keras.layers.RandomContrast(0.10),
], name="train_augmentation")

# %%
def apply_train_augmentation(images, labels):
    images = augmentation(images, training=True)
    return images, labels

# %%
train_paths = df_train["path"].values
train_labels = df_train["label"].values.astype(np.int32)

val_paths = df_val["path"].values
val_labels = df_val["label"].values.astype(np.int32)

test_paths = df_test["path"].values
test_labels = df_test["label"].values.astype(np.int32)

# %%
train_ds_base = tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
val_ds_base = tf.data.Dataset.from_tensor_slices((val_paths, val_labels))
test_ds_base = tf.data.Dataset.from_tensor_slices((test_paths, test_labels))

# %%
train_ds = train_ds_base.map(
    load_image_grayscale_rgb,
    num_parallel_calls=AUTOTUNE
)

if USE_CACHE:
    train_ds = train_ds.cache()

train_ds = (
    train_ds
    .shuffle(buffer_size=len(df_train), seed=SEED, reshuffle_each_iteration=True)
    .batch(BATCH_SIZE)
    .map(apply_train_augmentation, num_parallel_calls=AUTOTUNE)
    .prefetch(AUTOTUNE)
)

val_ds = val_ds_base.map(
    load_image_grayscale_rgb,
    num_parallel_calls=AUTOTUNE
)

if USE_CACHE:
    val_ds = val_ds.cache()

val_ds = (
    val_ds
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

test_ds = test_ds_base.map(
    load_image_grayscale_rgb,
    num_parallel_calls=AUTOTUNE
)

if USE_CACHE:
    test_ds = test_ds.cache()

test_ds = (
    test_ds
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

# %%
for images, labels in train_ds.take(1):
    print("train images:", images.shape, images.dtype)
    print("train labels:", labels.shape, labels.numpy())
    print("pixel min:", tf.reduce_min(images).numpy())
    print("pixel max:", tf.reduce_max(images).numpy())
# Out:
# train images: (8, 512, 512, 3) <dtype: 'float32'>
# train labels: (8,) [0 3 3 3 3 0 0 3]
# pixel min: 0.0
# pixel max: 243.27707

# %%
for images, labels in train_ds.take(1):
    print("images shape:", images.shape)
    print("images dtype:", images.dtype)
    print("labels shape:", labels.shape)
    print("labels example:", labels.numpy()[:10])
    print("pixel min:", tf.reduce_min(images).numpy())
    print("pixel max:", tf.reduce_max(images).numpy())

    INPUT_CHANNELS = images.shape[-1]
    PIXEL_MAX = float(tf.reduce_max(images).numpy())

print("INPUT_CHANNELS:", INPUT_CHANNELS)
print("PIXEL_MAX:", PIXEL_MAX)

if INPUT_CHANNELS != 3:
    raise ValueError(
        f"DenseNet121 ожидает 3 канала. Сейчас каналов: {INPUT_CHANNELS}. "
        "Проверьте подготовку датасета: grayscale должен быть продублирован в RGB."
    )

if "class_weight_dict" not in globals():
    raise RuntimeError("Не найдена переменная class_weight_dict.")

SCALE_0_1_TO_255 = PIXEL_MAX <= 1.5
print("SCALE_0_1_TO_255:", SCALE_0_1_TO_255)
print("class_weight_dict:")
print(class_weight_dict)
print("type:", type(class_weight_dict))
# Out:
# images shape: (8, 512, 512, 3)
# images dtype: <dtype: 'float32'>
# labels shape: (8,)
# labels example: [3 0 0 3 3 2 3 0]
# pixel min: 0.0
# pixel max: 239.95955
# INPUT_CHANNELS: 3
# PIXEL_MAX: 239.9595489501953
# SCALE_0_1_TO_255: False
# class_weight_dict:
# {0: 0.7686170212765957, 1: 1.6055555555555556, 2: 2.408333333333333, 3: 0.6020833333333333}
# type: <class 'dict'>

# %%
from pathlib import Path
from datetime import datetime
import json

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    roc_auc_score,
    roc_curve,
    auc
)
from sklearn.preprocessing import label_binarize

# %%
@tf.keras.utils.register_keras_serializable(package="custom")
class SparseMacroF1(tf.keras.metrics.Metric):
    def __init__(self, num_classes, name="macro_f1", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = int(num_classes)

        self.cm = self.add_weight(
            name="confusion_matrix",
            shape=(self.num_classes, self.num_classes),
            initializer="zeros",
            dtype=tf.float32
        )

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.reshape(tf.cast(y_true, tf.int32), [-1])
        y_pred = tf.argmax(y_pred, axis=-1, output_type=tf.int32)

        cm_batch = tf.math.confusion_matrix(
            y_true,
            y_pred,
            num_classes=self.num_classes,
            dtype=tf.float32
        )

        self.cm.assign_add(cm_batch)

    def result(self):
        tp = tf.linalg.diag_part(self.cm)
        fp = tf.reduce_sum(self.cm, axis=0) - tp
        fn = tf.reduce_sum(self.cm, axis=1) - tp

        precision = tf.math.divide_no_nan(tp, tp + fp)
        recall = tf.math.divide_no_nan(tp, tp + fn)

        f1 = tf.math.divide_no_nan(
            2.0 * precision * recall,
            precision + recall
        )

        return tf.reduce_mean(f1)

    def reset_state(self):
        self.cm.assign(tf.zeros_like(self.cm))

    def get_config(self):
        config = super().get_config()
        config.update({"num_classes": self.num_classes})
        return config
    
@tf.keras.utils.register_keras_serializable(package="custom")
class SparseMacroAUC(tf.keras.metrics.Metric):
    def __init__(self, num_classes, name="macro_auc", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = int(num_classes)

        self.auc = tf.keras.metrics.AUC(
            curve="ROC",
            multi_label=True,
            num_labels=self.num_classes,
            name=f"{name}_inner"
        )

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.reshape(tf.cast(y_true, tf.int32), [-1])
        y_true = tf.one_hot(y_true, depth=self.num_classes)

        self.auc.update_state(
            y_true,
            y_pred,
            sample_weight=sample_weight
        )

    def result(self):
        return self.auc.result()

    def reset_state(self):
        self.auc.reset_state()

    def get_config(self):
        config = super().get_config()
        config.update({"num_classes": self.num_classes})
        return config

@tf.keras.utils.register_keras_serializable(package="custom")
class SparseMacroPrecision(tf.keras.metrics.Metric):
    def __init__(self, num_classes, name="macro_precision", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = int(num_classes)

        self.cm = self.add_weight(
            name="confusion_matrix",
            shape=(self.num_classes, self.num_classes),
            initializer="zeros",
            dtype=tf.float32
        )

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.reshape(tf.cast(y_true, tf.int32), [-1])
        y_pred = tf.argmax(y_pred, axis=-1, output_type=tf.int32)

        cm_batch = tf.math.confusion_matrix(
            y_true,
            y_pred,
            num_classes=self.num_classes,
            dtype=tf.float32
        )

        self.cm.assign_add(cm_batch)

    def result(self):
        tp = tf.linalg.diag_part(self.cm)
        fp = tf.reduce_sum(self.cm, axis=0) - tp

        precision = tf.math.divide_no_nan(tp, tp + fp)

        return tf.reduce_mean(precision)

    def reset_state(self):
        self.cm.assign(tf.zeros_like(self.cm))

    def get_config(self):
        config = super().get_config()
        config.update({"num_classes": self.num_classes})
        return config
    
@tf.keras.utils.register_keras_serializable(package="custom")
class SparseMacroRecall(tf.keras.metrics.Metric):
    def __init__(self, num_classes, name="macro_recall", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = int(num_classes)

        self.cm = self.add_weight(
            name="confusion_matrix",
            shape=(self.num_classes, self.num_classes),
            initializer="zeros",
            dtype=tf.float32
        )

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.reshape(tf.cast(y_true, tf.int32), [-1])
        y_pred = tf.argmax(y_pred, axis=-1, output_type=tf.int32)

        cm_batch = tf.math.confusion_matrix(
            y_true,
            y_pred,
            num_classes=self.num_classes,
            dtype=tf.float32
        )

        self.cm.assign_add(cm_batch)

    def result(self):
        tp = tf.linalg.diag_part(self.cm)
        fn = tf.reduce_sum(self.cm, axis=1) - tp

        recall = tf.math.divide_no_nan(tp, tp + fn)

        return tf.reduce_mean(recall)

    def reset_state(self):
        self.cm.assign(tf.zeros_like(self.cm))

    def get_config(self):
        config = super().get_config()
        config.update({"num_classes": self.num_classes})
        return config

# %%
@tf.keras.utils.register_keras_serializable(package="custom")
class VGG16Preprocess(tf.keras.layers.Layer):
    def __init__(self, scale_0_1_to_255=False, **kwargs):
        super().__init__(**kwargs)
        self.scale_0_1_to_255 = bool(scale_0_1_to_255)

    def call(self, inputs):
        x = tf.cast(inputs, tf.float32)

        if self.scale_0_1_to_255:
            x = x * 255.0

        x = tf.keras.applications.vgg16.preprocess_input(x)

        return x

    def get_config(self):
        config = super().get_config()
        config.update({
            "scale_0_1_to_255": self.scale_0_1_to_255
        })
        return config

# %%
tf.keras.backend.clear_session()

from tensorflow.keras import layers, Model, regularizers

inputs = tf.keras.Input(
    shape=(MODEL_SIZE, MODEL_SIZE, 3),
    name="input_image"
)

x = VGG16Preprocess(
    scale_0_1_to_255=SCALE_0_1_TO_255,
    name="vgg16_preprocess"
)(inputs)

base = tf.keras.applications.VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(MODEL_SIZE, MODEL_SIZE, 3)
)

base.trainable = False

features = base(x, training=False)

gap = layers.GlobalAveragePooling2D(name="global_avg_pool")(features)
gmp = layers.GlobalMaxPooling2D(name="global_max_pool")(features)

x = layers.Concatenate(name="concat_avg_max_pool")([gap, gmp])

x = layers.LayerNormalization(
    epsilon=1e-6,
    name="head_layer_norm"
)(x)

x = layers.Dropout(
    0.45,
    name="dropout_1"
)(x)

x = layers.Dense(
    256,
    activation="relu",
    kernel_regularizer=regularizers.l2(1e-4),
    name="dense_head"
)(x)

x = layers.Dropout(
    0.35,
    name="dropout_2"
)(x)

outputs = layers.Dense(
    NUM_CLASSES,
    activation="softmax",
    kernel_regularizer=regularizers.l2(1e-4),
    name="classifier"
)(x)

model = Model(
    inputs=inputs,
    outputs=outputs,
    name="vgg16_hep2_classifier_precision_recall"
)

model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\Glush\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# Model: "vgg16_hep2_classifier_precision_recall"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_image         │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16_preprocess    │ (None, 512, 512,  │          0 │ input_image[0][0] │
# │ (VGG16Preprocess)   │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 16, 16,    │ 14,714,688 │ vgg16_preprocess… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_avg_pool     │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pool     │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat_avg_max_pool │ (None, 1024)      │          0 │ global_avg_pool[… │
# │ (Concatenate)       │                   │            │ global_max_pool[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_layer_norm     │ (None, 1024)      │      2,048 │ concat_avg_max_p… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1024)      │          0 │ head_layer_norm[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_head (Dense)  │ (None, 256)       │    262,400 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ dense_head[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier (Dense)  │ (None, 4)         │      1,028 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 14,980,164 (57.14 MB)
#  Trainable params: 265,476 (1.01 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
stage1_metrics = [
    tf.keras.metrics.SparseCategoricalAccuracy(name="acc"),
    tf.keras.metrics.SparseTopKCategoricalAccuracy(k=2, name="top2_acc"),
    SparseMacroPrecision(num_classes=NUM_CLASSES, name="macro_precision"),
    SparseMacroRecall(num_classes=NUM_CLASSES, name="macro_recall"),
    SparseMacroF1(num_classes=NUM_CLASSES, name="macro_f1"),
    SparseMacroAUC(num_classes=NUM_CLASSES, name="macro_auc"),
]
try:
    optimizer_stage1 = tf.keras.optimizers.AdamW(
        learning_rate=2e-4,
        weight_decay=1e-4
    )
except AttributeError:
    optimizer_stage1 = tf.keras.optimizers.Adam(
        learning_rate=2e-4
    )

model.compile(
    optimizer=optimizer_stage1,
    loss="sparse_categorical_crossentropy",
    metrics=stage1_metrics
)

# %%
stage1_weights_path = CHECKPOINT_DIR / "best_stage1.weights.h5"

callbacks_stage1 = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=str(stage1_weights_path),
        monitor="val_macro_f1",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
        verbose=1
    ),

    tf.keras.callbacks.EarlyStopping(
        monitor="val_macro_f1",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),

    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        mode="min",
        factor=0.3,
        patience=3,
        min_lr=1e-6,
        verbose=1
    ),

    tf.keras.callbacks.CSVLogger(
        filename=str(REPORTS_DIR / "stage1_training_log.csv")
    )
]

# %%
history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    class_weight=class_weight_dict,
    callbacks=callbacks_stage1
)
# Out:
# Epoch 1/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.3903 - loss: 1.9470 - macro_auc: 0.6192 - macro_f1: 0.3440 - macro_precision: 0.3645 - macro_recall: 0.3551 - top2_acc: 0.6474
# Epoch 1: val_macro_f1 improved from None to 0.58690, saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
#
# Epoch 1: finished saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 371s 5s/step - acc: 0.4671 - loss: 1.6386 - macro_auc: 0.6892 - macro_f1: 0.4064 - macro_precision: 0.4234 - macro_recall: 0.4149 - top2_acc: 0.7180 - val_acc: 0.7903 - val_loss: 0.6458 - val_macro_auc: 0.9430 - val_macro_f1: 0.5869 - val_macro_precision: 0.5556 - val_macro_recall: 0.6302 - val_top2_acc: 0.9113 - learning_rate: 2.0000e-04
# Epoch 2/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.5879 - loss: 1.1256 - macro_auc: 0.8329 - macro_f1: 0.5263 - macro_precision: 0.5306 - macro_recall: 0.5367 - top2_acc: 0.8488
# Epoch 2: val_macro_f1 improved from 0.58690 to 0.68170, saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
#
# Epoch 2: finished saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 359s 5s/step - acc: 0.6228 - loss: 1.0671 - macro_auc: 0.8470 - macro_f1: 0.5418 - macro_precision: 0.5406 - macro_recall: 0.5546 - top2_acc: 0.8720 - val_acc: 0.8387 - val_loss: 0.4624 - val_macro_auc: 0.9666 - val_macro_f1: 0.6817 - val_macro_precision: 0.8387 - val_macro_recall: 0.6839 - val_top2_acc: 0.9597 - learning_rate: 2.0000e-04
# Epoch 3/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.6422 - loss: 1.1470 - macro_auc: 0.8484 - macro_f1: 0.5535 - macro_precision: 0.5575 - macro_recall: 0.5635 - top2_acc: 0.8654
# Epoch 3: val_macro_f1 improved from 0.68170 to 0.70753, saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
#
# Epoch 3: finished saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 355s 5s/step - acc: 0.6920 - loss: 0.9891 - macro_auc: 0.8793 - macro_f1: 0.5993 - macro_precision: 0.5996 - macro_recall: 0.6090 - top2_acc: 0.8875 - val_acc: 0.8790 - val_loss: 0.4356 - val_macro_auc: 0.9657 - val_macro_f1: 0.7075 - val_macro_precision: 0.8892 - val_macro_recall: 0.7505 - val_top2_acc: 0.9919 - learning_rate: 2.0000e-04
# Epoch 4/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.7251 - loss: 0.8456 - macro_auc: 0.9029 - macro_f1: 0.6238 - macro_precision: 0.6236 - macro_recall: 0.6331 - top2_acc: 0.9133
# Epoch 4: val_macro_f1 improved from 0.70753 to 0.74803, saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
#
# Epoch 4: finished saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 356s 5s/step - acc: 0.7457 - loss: 0.7940 - macro_auc: 0.9173 - macro_f1: 0.6559 - macro_precision: 0.6518 - macro_recall: 0.6654 - top2_acc: 0.9221 - val_acc: 0.8548 - val_loss: 0.4160 - val_macro_auc: 0.9682 - val_macro_f1: 0.7480 - val_macro_precision: 0.7527 - val_macro_recall: 0.7474 - val_top2_acc: 0.9839 - learning_rate: 2.0000e-04
# Epoch 5/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.7780 - loss: 0.8059 - macro_auc: 0.9139 - macro_f1: 0.6610 - macro_precision: 0.6615 - macro_recall: 0.6758 - top2_acc: 0.9366
# Epoch 5: val_macro_f1 did not improve from 0.74803
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 353s 5s/step - acc: 0.7855 - loss: 0.7745 - macro_auc: 0.9243 - macro_f1: 0.6990 - macro_precision: 0.6952 - macro_recall: 0.7052 - top2_acc: 0.9377 - val_acc: 0.8468 - val_loss: 0.4101 - val_macro_auc: 0.9703 - val_macro_f1: 0.7365 - val_macro_precision: 0.7817 - val_macro_recall: 0.7655 - val_top2_acc: 0.9839 - learning_rate: 2.0000e-04
# Epoch 6/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.7819 - loss: 0.7518 - macro_auc: 0.9207 - macro_f1: 0.6531 - macro_precision: 0.6562 - macro_recall: 0.6656 - top2_acc: 0.9409
# Epoch 6: val_macro_f1 improved from 0.74803 to 0.74944, saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
#
# Epoch 6: finished saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 352s 5s/step - acc: 0.7803 - loss: 0.7628 - macro_auc: 0.9271 - macro_f1: 0.6942 - macro_precision: 0.6938 - macro_recall: 0.7076 - top2_acc: 0.9360 - val_acc: 0.8548 - val_loss: 0.3931 - val_macro_auc: 0.9673 - val_macro_f1: 0.7494 - val_macro_precision: 0.7593 - val_macro_recall: 0.7491 - val_top2_acc: 0.9919 - learning_rate: 2.0000e-04
# Epoch 7/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.7830 - loss: 0.7146 - macro_auc: 0.9313 - macro_f1: 0.6642 - macro_precision: 0.6656 - macro_recall: 0.6694 - top2_acc: 0.9455
# Epoch 7: val_macro_f1 did not improve from 0.74944
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 351s 5s/step - acc: 0.7855 - loss: 0.7299 - macro_auc: 0.9351 - macro_f1: 0.6862 - macro_precision: 0.6857 - macro_recall: 0.6923 - top2_acc: 0.9464 - val_acc: 0.8065 - val_loss: 0.4846 - val_macro_auc: 0.9650 - val_macro_f1: 0.6142 - val_macro_precision: 0.6051 - val_macro_recall: 0.6812 - val_top2_acc: 0.9919 - learning_rate: 2.0000e-04
# Epoch 8/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.8084 - loss: 0.7449 - macro_auc: 0.9277 - macro_f1: 0.6892 - macro_precision: 0.6903 - macro_recall: 0.6963 - top2_acc: 0.9541
# Epoch 8: val_macro_f1 improved from 0.74944 to 0.76134, saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
#
# Epoch 8: finished saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 353s 5s/step - acc: 0.8010 - loss: 0.7394 - macro_auc: 0.9336 - macro_f1: 0.6965 - macro_precision: 0.6952 - macro_recall: 0.7019 - top2_acc: 0.9481 - val_acc: 0.8629 - val_loss: 0.3737 - val_macro_auc: 0.9689 - val_macro_f1: 0.7613 - val_macro_precision: 0.7702 - val_macro_recall: 0.7623 - val_top2_acc: 0.9919 - learning_rate: 2.0000e-04
# Epoch 9/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.7892 - loss: 0.7283 - macro_auc: 0.9196 - macro_f1: 0.6623 - macro_precision: 0.6624 - macro_recall: 0.6744 - top2_acc: 0.9454
# Epoch 9: val_macro_f1 did not improve from 0.76134
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 351s 5s/step - acc: 0.7820 - loss: 0.7292 - macro_auc: 0.9286 - macro_f1: 0.6719 - macro_precision: 0.6703 - macro_recall: 0.6792 - top2_acc: 0.9446 - val_acc: 0.8548 - val_loss: 0.3632 - val_macro_auc: 0.9766 - val_macro_f1: 0.7382 - val_macro_precision: 0.8761 - val_macro_recall: 0.7577 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-04
# Epoch 10/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.8363 - loss: 0.6274 - macro_auc: 0.9450 - macro_f1: 0.7227 - macro_precision: 0.7223 - macro_recall: 0.7324 - top2_acc: 0.9745
# Epoch 10: val_macro_f1 improved from 0.76134 to 0.76155, saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
#
# Epoch 10: finished saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 349s 5s/step - acc: 0.8270 - loss: 0.6399 - macro_auc: 0.9451 - macro_f1: 0.7344 - macro_precision: 0.7315 - macro_recall: 0.7421 - top2_acc: 0.9671 - val_acc: 0.8629 - val_loss: 0.3782 - val_macro_auc: 0.9717 - val_macro_f1: 0.7616 - val_macro_precision: 0.8321 - val_macro_recall: 0.7700 - val_top2_acc: 0.9919 - learning_rate: 2.0000e-04
# Epoch 11/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.8293 - loss: 0.5789 - macro_auc: 0.9539 - macro_f1: 0.7353 - macro_precision: 0.7352 - macro_recall: 0.7516 - top2_acc: 0.9537
# Epoch 11: val_macro_f1 improved from 0.76155 to 0.78641, saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
#
# Epoch 11: finished saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 349s 5s/step - acc: 0.8062 - loss: 0.6310 - macro_auc: 0.9465 - macro_f1: 0.7042 - macro_precision: 0.7024 - macro_recall: 0.7151 - top2_acc: 0.9567 - val_acc: 0.8871 - val_loss: 0.3507 - val_macro_auc: 0.9706 - val_macro_f1: 0.7864 - val_macro_precision: 0.8070 - val_macro_recall: 0.7879 - val_top2_acc: 0.9919 - learning_rate: 2.0000e-04
# Epoch 12/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.7874 - loss: 0.6451 - macro_auc: 0.9503 - macro_f1: 0.7031 - macro_precision: 0.7072 - macro_recall: 0.7079 - top2_acc: 0.9723
# Epoch 12: val_macro_f1 improved from 0.78641 to 0.80143, saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
#
# Epoch 12: finished saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage1.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 352s 5s/step - acc: 0.7837 - loss: 0.6481 - macro_auc: 0.9437 - macro_f1: 0.6723 - macro_precision: 0.6733 - macro_recall: 0.6805 - top2_acc: 0.9671 - val_acc: 0.8952 - val_loss: 0.3531 - val_macro_auc: 0.9740 - val_macro_f1: 0.8014 - val_macro_precision: 0.8349 - val_macro_recall: 0.8011 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-04
# Epoch 13/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.8035 - loss: 0.6539 - macro_auc: 0.9409 - macro_f1: 0.6851 - macro_precision: 0.6883 - macro_recall: 0.6860 - top2_acc: 0.9755
# Epoch 13: val_macro_f1 did not improve from 0.80143
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 356s 5s/step - acc: 0.8062 - loss: 0.6503 - macro_auc: 0.9448 - macro_f1: 0.7090 - macro_precision: 0.7075 - macro_recall: 0.7115 - top2_acc: 0.9706 - val_acc: 0.8790 - val_loss: 0.3657 - val_macro_auc: 0.9742 - val_macro_f1: 0.7351 - val_macro_precision: 0.8892 - val_macro_recall: 0.7635 - val_top2_acc: 0.9919 - learning_rate: 2.0000e-04
# Epoch 14/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.8077 - loss: 0.7327 - macro_auc: 0.9372 - macro_f1: 0.7364 - macro_precision: 0.7342 - macro_recall: 0.7481 - top2_acc: 0.9452
# Epoch 14: val_macro_f1 did not improve from 0.80143
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 5.999999848427251e-05.
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 348s 5s/step - acc: 0.8183 - loss: 0.6106 - macro_auc: 0.9526 - macro_f1: 0.7321 - macro_precision: 0.7288 - macro_recall: 0.7439 - top2_acc: 0.9637 - val_acc: 0.8710 - val_loss: 0.3616 - val_macro_auc: 0.9710 - val_macro_f1: 0.7498 - val_macro_precision: 0.8248 - val_macro_recall: 0.7633 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-04
# Epoch 15/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.8523 - loss: 0.5123 - macro_auc: 0.9551 - macro_f1: 0.7487 - macro_precision: 0.7521 - macro_recall: 0.7563 - top2_acc: 0.9767
# Epoch 15: val_macro_f1 did not improve from 0.80143
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 354s 5s/step - acc: 0.8408 - loss: 0.5452 - macro_auc: 0.9613 - macro_f1: 0.7476 - macro_precision: 0.7458 - macro_recall: 0.7586 - top2_acc: 0.9775 - val_acc: 0.8548 - val_loss: 0.3819 - val_macro_auc: 0.9706 - val_macro_f1: 0.6889 - val_macro_precision: 0.8761 - val_macro_recall: 0.7317 - val_top2_acc: 0.9919 - learning_rate: 6.0000e-05
# Epoch 16/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.8298 - loss: 0.5934 - macro_auc: 0.9525 - macro_f1: 0.7315 - macro_precision: 0.7350 - macro_recall: 0.7406 - top2_acc: 0.9736
# Epoch 16: val_macro_f1 did not improve from 0.80143
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 354s 5s/step - acc: 0.8374 - loss: 0.5819 - macro_auc: 0.9548 - macro_f1: 0.7410 - macro_precision: 0.7369 - macro_recall: 0.7468 - top2_acc: 0.9758 - val_acc: 0.8790 - val_loss: 0.3592 - val_macro_auc: 0.9721 - val_macro_f1: 0.7617 - val_macro_precision: 0.8905 - val_macro_recall: 0.7764 - val_top2_acc: 0.9919 - learning_rate: 6.0000e-05
# Epoch 17/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.8705 - loss: 0.5219 - macro_auc: 0.9618 - macro_f1: 0.7792 - macro_precision: 0.7815 - macro_recall: 0.7847 - top2_acc: 0.9812
# Epoch 17: val_macro_f1 did not improve from 0.80143
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 350s 5s/step - acc: 0.8512 - loss: 0.5410 - macro_auc: 0.9615 - macro_f1: 0.7494 - macro_precision: 0.7485 - macro_recall: 0.7517 - top2_acc: 0.9810 - val_acc: 0.8629 - val_loss: 0.3469 - val_macro_auc: 0.9727 - val_macro_f1: 0.7383 - val_macro_precision: 0.7839 - val_macro_recall: 0.7501 - val_top2_acc: 0.9919 - learning_rate: 6.0000e-05
# Epoch 18/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.8513 - loss: 0.5310 - macro_auc: 0.9580 - macro_f1: 0.7682 - macro_precision: 0.7706 - macro_recall: 0.7778 - top2_acc: 0.9752
# Epoch 18: val_macro_f1 did not improve from 0.80143
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 357s 5s/step - acc: 0.8322 - loss: 0.5649 - macro_auc: 0.9567 - macro_f1: 0.7382 - macro_precision: 0.7356 - macro_recall: 0.7514 - top2_acc: 0.9671 - val_acc: 0.8629 - val_loss: 0.3456 - val_macro_auc: 0.9724 - val_macro_f1: 0.7383 - val_macro_precision: 0.7839 - val_macro_recall: 0.7501 - val_top2_acc: 0.9919 - learning_rate: 6.0000e-05
# Epoch 19/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.8158 - loss: 0.6060 - macro_auc: 0.9405 - macro_f1: 0.7110 - macro_precision: 0.7138 - macro_recall: 0.7240 - top2_acc: 0.9650
# Epoch 19: val_macro_f1 did not improve from 0.80143
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 352s 5s/step - acc: 0.8287 - loss: 0.5710 - macro_auc: 0.9559 - macro_f1: 0.7403 - macro_precision: 0.7352 - macro_recall: 0.7479 - top2_acc: 0.9671 - val_acc: 0.8629 - val_loss: 0.3688 - val_macro_auc: 0.9711 - val_macro_f1: 0.7202 - val_macro_precision: 0.7988 - val_macro_recall: 0.7441 - val_top2_acc: 0.9919 - learning_rate: 6.0000e-05
# Epoch 20/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.8287 - loss: 0.5778 - macro_auc: 0.9532 - macro_f1: 0.7253 - macro_precision: 0.7266 - macro_recall: 0.7292 - top2_acc: 0.9656
# Epoch 20: val_macro_f1 did not improve from 0.80143
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 353s 5s/step - acc: 0.8478 - loss: 0.5393 - macro_auc: 0.9622 - macro_f1: 0.7603 - macro_precision: 0.7564 - macro_recall: 0.7678 - top2_acc: 0.9740 - val_acc: 0.8548 - val_loss: 0.3699 - val_macro_auc: 0.9697 - val_macro_f1: 0.6874 - val_macro_precision: 0.7523 - val_macro_recall: 0.7248 - val_top2_acc: 0.9919 - learning_rate: 6.0000e-05
# Epoch 21/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.8505 - loss: 0.5145 - macro_auc: 0.9541 - macro_f1: 0.7394 - macro_precision: 0.7367 - macro_recall: 0.7494 - top2_acc: 0.9691
# Epoch 21: val_macro_f1 did not improve from 0.80143
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.7999999545281754e-05.
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 350s 5s/step - acc: 0.8391 - loss: 0.5630 - macro_auc: 0.9587 - macro_f1: 0.7499 - macro_precision: 0.7473 - macro_recall: 0.7584 - top2_acc: 0.9637 - val_acc: 0.8710 - val_loss: 0.3668 - val_macro_auc: 0.9707 - val_macro_f1: 0.7749 - val_macro_precision: 0.7984 - val_macro_recall: 0.7754 - val_top2_acc: 0.9919 - learning_rate: 6.0000e-05
# Epoch 22/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.8650 - loss: 0.5133 - macro_auc: 0.9620 - macro_f1: 0.7937 - macro_precision: 0.7945 - macro_recall: 0.8055 - top2_acc: 0.9746
# Epoch 22: val_macro_f1 did not improve from 0.80143
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 350s 5s/step - acc: 0.8599 - loss: 0.5118 - macro_auc: 0.9638 - macro_f1: 0.7768 - macro_precision: 0.7748 - macro_recall: 0.7834 - top2_acc: 0.9827 - val_acc: 0.8710 - val_loss: 0.3704 - val_macro_auc: 0.9712 - val_macro_f1: 0.7749 - val_macro_precision: 0.7984 - val_macro_recall: 0.7754 - val_top2_acc: 0.9919 - learning_rate: 1.8000e-05
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.

# %%
model.load_weights(stage1_weights_path)

base.trainable = True

for layer in base.layers:
    layer.trainable = False

# Размораживаем только последний блок VGG16
for layer in base.layers:
    if layer.name.startswith("block5"):
        layer.trainable = True

trainable_layers = sum(layer.trainable for layer in base.layers)

print("Backbone layers:", len(base.layers))
print("Trainable backbone layers:", trainable_layers)

for layer in base.layers:
    print(layer.name, layer.trainable)
# Out:
# Backbone layers: 19
# Trainable backbone layers: 4
# input_layer False
# block1_conv1 False
# block1_conv2 False
# block1_pool False
# block2_conv1 False
# block2_conv2 False
# block2_pool False
# block3_conv1 False
# block3_conv2 False
# block3_conv3 False
# block3_pool False
# block4_conv1 False
# block4_conv2 False
# block4_conv3 False
# block4_pool False
# block5_conv1 True
# block5_conv2 True
# block5_conv3 True
# block5_pool True

# %%
stage2_metrics = [
    tf.keras.metrics.SparseCategoricalAccuracy(name="acc"),
    tf.keras.metrics.SparseTopKCategoricalAccuracy(k=2, name="top2_acc"),
    SparseMacroPrecision(num_classes=NUM_CLASSES, name="macro_precision"),
    SparseMacroRecall(num_classes=NUM_CLASSES, name="macro_recall"),
    SparseMacroF1(num_classes=NUM_CLASSES, name="macro_f1"),
    SparseMacroAUC(num_classes=NUM_CLASSES, name="macro_auc"),
]
try:
    optimizer_stage2 = tf.keras.optimizers.AdamW(
        learning_rate=2e-6,
        weight_decay=1e-5
    )
except AttributeError:
    optimizer_stage2 = tf.keras.optimizers.Adam(
        learning_rate=2e-6
    )

model.compile(
    optimizer=optimizer_stage2,
    loss="sparse_categorical_crossentropy",
    metrics=stage2_metrics
)

# %%
stage2_weights_path = CHECKPOINT_DIR / "best_stage2.weights.h5"

callbacks_stage2 = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=str(stage2_weights_path),
        monitor="val_macro_f1",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
        verbose=1
    ),

    tf.keras.callbacks.EarlyStopping(
        monitor="val_macro_f1",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),

    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        mode="min",
        factor=0.3,
        patience=3,
        min_lr=1e-7,
        verbose=1
    ),

    tf.keras.callbacks.CSVLogger(
        filename=str(REPORTS_DIR / "stage2_training_log.csv")
    )
]

# %%
history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    class_weight=class_weight_dict,
    callbacks=callbacks_stage2
)
# Out:
# Epoch 1/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8676 - loss: 0.5956 - macro_auc: 0.9550 - macro_f1: 0.7846 - macro_precision: 0.7911 - macro_recall: 0.7871 - top2_acc: 0.9774
# Epoch 1: val_macro_f1 improved from None to 0.80442, saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage2.weights.h5
#
# Epoch 1: finished saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage2.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 397s 5s/step - acc: 0.8599 - loss: 0.5790 - macro_auc: 0.9574 - macro_f1: 0.7775 - macro_precision: 0.7748 - macro_recall: 0.7810 - top2_acc: 0.9723 - val_acc: 0.8871 - val_loss: 0.3480 - val_macro_auc: 0.9738 - val_macro_f1: 0.8044 - val_macro_precision: 0.8227 - val_macro_recall: 0.8009 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-06
# Epoch 2/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8448 - loss: 0.5349 - macro_auc: 0.9611 - macro_f1: 0.7458 - macro_precision: 0.7522 - macro_recall: 0.7474 - top2_acc: 0.9671
# Epoch 2: val_macro_f1 did not improve from 0.80442
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 391s 5s/step - acc: 0.8287 - loss: 0.5682 - macro_auc: 0.9595 - macro_f1: 0.7321 - macro_precision: 0.7310 - macro_recall: 0.7334 - top2_acc: 0.9706 - val_acc: 0.8790 - val_loss: 0.3446 - val_macro_auc: 0.9742 - val_macro_f1: 0.7909 - val_macro_precision: 0.8026 - val_macro_recall: 0.7878 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-06
# Epoch 3/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - acc: 0.8301 - loss: 0.5695 - macro_auc: 0.9523 - macro_f1: 0.7296 - macro_precision: 0.7281 - macro_recall: 0.7384 - top2_acc: 0.9662
# Epoch 3: val_macro_f1 did not improve from 0.80442
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 388s 5s/step - acc: 0.8356 - loss: 0.5688 - macro_auc: 0.9568 - macro_f1: 0.7482 - macro_precision: 0.7452 - macro_recall: 0.7567 - top2_acc: 0.9706 - val_acc: 0.8629 - val_loss: 0.3413 - val_macro_auc: 0.9743 - val_macro_f1: 0.7742 - val_macro_precision: 0.7878 - val_macro_recall: 0.7683 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-06
# Epoch 4/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8273 - loss: 0.5642 - macro_auc: 0.9583 - macro_f1: 0.7181 - macro_precision: 0.7194 - macro_recall: 0.7246 - top2_acc: 0.9755
# Epoch 4: val_macro_f1 did not improve from 0.80442
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 393s 5s/step - acc: 0.8235 - loss: 0.5736 - macro_auc: 0.9556 - macro_f1: 0.7385 - macro_precision: 0.7335 - macro_recall: 0.7489 - top2_acc: 0.9775 - val_acc: 0.8710 - val_loss: 0.3351 - val_macro_auc: 0.9742 - val_macro_f1: 0.7799 - val_macro_precision: 0.7921 - val_macro_recall: 0.7746 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-06
# Epoch 5/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8509 - loss: 0.5693 - macro_auc: 0.9547 - macro_f1: 0.7627 - macro_precision: 0.7619 - macro_recall: 0.7668 - top2_acc: 0.9656
# Epoch 5: val_macro_f1 did not improve from 0.80442
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 396s 5s/step - acc: 0.8512 - loss: 0.5605 - macro_auc: 0.9584 - macro_f1: 0.7627 - macro_precision: 0.7592 - macro_recall: 0.7674 - top2_acc: 0.9689 - val_acc: 0.8629 - val_loss: 0.3400 - val_macro_auc: 0.9745 - val_macro_f1: 0.7742 - val_macro_precision: 0.7878 - val_macro_recall: 0.7683 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-06
# Epoch 6/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8537 - loss: 0.5492 - macro_auc: 0.9569 - macro_f1: 0.7499 - macro_precision: 0.7625 - macro_recall: 0.7611 - top2_acc: 0.9850
# Epoch 6: val_macro_f1 did not improve from 0.80442
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 409s 6s/step - acc: 0.8426 - loss: 0.5698 - macro_auc: 0.9591 - macro_f1: 0.7443 - macro_precision: 0.7474 - macro_recall: 0.7497 - top2_acc: 0.9792 - val_acc: 0.8871 - val_loss: 0.3199 - val_macro_auc: 0.9759 - val_macro_f1: 0.7995 - val_macro_precision: 0.8169 - val_macro_recall: 0.7940 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-06
# Epoch 7/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8641 - loss: 0.4977 - macro_auc: 0.9580 - macro_f1: 0.7669 - macro_precision: 0.7695 - macro_recall: 0.7789 - top2_acc: 0.9922
# Epoch 7: val_macro_f1 did not improve from 0.80442
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 399s 5s/step - acc: 0.8633 - loss: 0.5221 - macro_auc: 0.9635 - macro_f1: 0.7828 - macro_precision: 0.7792 - macro_recall: 0.7912 - top2_acc: 0.9844 - val_acc: 0.8871 - val_loss: 0.3148 - val_macro_auc: 0.9756 - val_macro_f1: 0.7995 - val_macro_precision: 0.8169 - val_macro_recall: 0.7940 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-06
# Epoch 8/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8395 - loss: 0.5116 - macro_auc: 0.9652 - macro_f1: 0.7311 - macro_precision: 0.7278 - macro_recall: 0.7383 - top2_acc: 0.9883
# Epoch 8: val_macro_f1 did not improve from 0.80442
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 396s 5s/step - acc: 0.8443 - loss: 0.4966 - macro_auc: 0.9676 - macro_f1: 0.7498 - macro_precision: 0.7464 - macro_recall: 0.7549 - top2_acc: 0.9844 - val_acc: 0.8790 - val_loss: 0.3180 - val_macro_auc: 0.9758 - val_macro_f1: 0.7938 - val_macro_precision: 0.8125 - val_macro_recall: 0.7878 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-06
# Epoch 9/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8428 - loss: 0.5559 - macro_auc: 0.9605 - macro_f1: 0.7492 - macro_precision: 0.7474 - macro_recall: 0.7578 - top2_acc: 0.9711
# Epoch 9: val_macro_f1 did not improve from 0.80442
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 394s 5s/step - acc: 0.8547 - loss: 0.5186 - macro_auc: 0.9635 - macro_f1: 0.7590 - macro_precision: 0.7572 - macro_recall: 0.7646 - top2_acc: 0.9810 - val_acc: 0.8790 - val_loss: 0.3093 - val_macro_auc: 0.9770 - val_macro_f1: 0.7938 - val_macro_precision: 0.8125 - val_macro_recall: 0.7878 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-06
# Epoch 10/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8746 - loss: 0.4591 - macro_auc: 0.9429 - macro_f1: 0.7656 - macro_precision: 0.7621 - macro_recall: 0.7762 - top2_acc: 0.9750
# Epoch 10: val_macro_f1 did not improve from 0.80442
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 396s 5s/step - acc: 0.8564 - loss: 0.5242 - macro_auc: 0.9640 - macro_f1: 0.7710 - macro_precision: 0.7678 - macro_recall: 0.7762 - top2_acc: 0.9792 - val_acc: 0.8871 - val_loss: 0.3174 - val_macro_auc: 0.9786 - val_macro_f1: 0.8044 - val_macro_precision: 0.8227 - val_macro_recall: 0.8009 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-06
# Epoch 11/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8664 - loss: 0.5141 - macro_auc: 0.9679 - macro_f1: 0.7985 - macro_precision: 0.8005 - macro_recall: 0.8084 - top2_acc: 0.9885
# Epoch 11: val_macro_f1 improved from 0.80442 to 0.80508, saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage2.weights.h5
#
# Epoch 11: finished saving model to experiments\VGG16_20260419_185227\checkpoints\best_stage2.weights.h5
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 398s 5s/step - acc: 0.8564 - loss: 0.4989 - macro_auc: 0.9663 - macro_f1: 0.7681 - macro_precision: 0.7672 - macro_recall: 0.7798 - top2_acc: 0.9827 - val_acc: 0.8952 - val_loss: 0.3024 - val_macro_auc: 0.9791 - val_macro_f1: 0.8051 - val_macro_precision: 0.8215 - val_macro_recall: 0.8003 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-06
# Epoch 12/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8647 - loss: 0.4885 - macro_auc: 0.9675 - macro_f1: 0.7948 - macro_precision: 0.7926 - macro_recall: 0.7994 - top2_acc: 0.9827
# Epoch 12: val_macro_f1 did not improve from 0.80508
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 397s 5s/step - acc: 0.8529 - loss: 0.4999 - macro_auc: 0.9671 - macro_f1: 0.7730 - macro_precision: 0.7686 - macro_recall: 0.7798 - top2_acc: 0.9844 - val_acc: 0.8952 - val_loss: 0.2969 - val_macro_auc: 0.9786 - val_macro_f1: 0.8051 - val_macro_precision: 0.8215 - val_macro_recall: 0.8003 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-06
# Epoch 13/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8701 - loss: 0.4739 - macro_auc: 0.9690 - macro_f1: 0.7833 - macro_precision: 0.7884 - macro_recall: 0.7849 - top2_acc: 0.9921
# Epoch 13: val_macro_f1 did not improve from 0.80508
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 410s 6s/step - acc: 0.8651 - loss: 0.5194 - macro_auc: 0.9650 - macro_f1: 0.7750 - macro_precision: 0.7736 - macro_recall: 0.7794 - top2_acc: 0.9862 - val_acc: 0.8952 - val_loss: 0.3029 - val_macro_auc: 0.9786 - val_macro_f1: 0.8051 - val_macro_precision: 0.8215 - val_macro_recall: 0.8003 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-06
# Epoch 14/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8685 - loss: 0.5070 - macro_auc: 0.9566 - macro_f1: 0.7898 - macro_precision: 0.7897 - macro_recall: 0.7945 - top2_acc: 0.9922
# Epoch 14: val_macro_f1 did not improve from 0.80508
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 399s 5s/step - acc: 0.8616 - loss: 0.5097 - macro_auc: 0.9658 - macro_f1: 0.7837 - macro_precision: 0.7798 - macro_recall: 0.7883 - top2_acc: 0.9862 - val_acc: 0.8871 - val_loss: 0.3078 - val_macro_auc: 0.9787 - val_macro_f1: 0.7995 - val_macro_precision: 0.8169 - val_macro_recall: 0.7940 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-06
# Epoch 15/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8725 - loss: 0.4560 - macro_auc: 0.9694 - macro_f1: 0.7692 - macro_precision: 0.7696 - macro_recall: 0.7744 - top2_acc: 0.9891
# Epoch 15: val_macro_f1 did not improve from 0.80508
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 5.999999984851456e-07.
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 420s 6s/step - acc: 0.8599 - loss: 0.4882 - macro_auc: 0.9698 - macro_f1: 0.7782 - macro_precision: 0.7763 - macro_recall: 0.7821 - top2_acc: 0.9827 - val_acc: 0.8952 - val_loss: 0.3017 - val_macro_auc: 0.9783 - val_macro_f1: 0.8051 - val_macro_precision: 0.8215 - val_macro_recall: 0.8003 - val_top2_acc: 1.0000 - learning_rate: 2.0000e-06
# Epoch 16/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8654 - loss: 0.4892 - macro_auc: 0.9693 - macro_f1: 0.7821 - macro_precision: 0.7849 - macro_recall: 0.7887 - top2_acc: 0.9926
# Epoch 16: val_macro_f1 did not improve from 0.80508
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 398s 5s/step - acc: 0.8737 - loss: 0.4826 - macro_auc: 0.9689 - macro_f1: 0.7881 - macro_precision: 0.7874 - macro_recall: 0.7924 - top2_acc: 0.9896 - val_acc: 0.8952 - val_loss: 0.3017 - val_macro_auc: 0.9781 - val_macro_f1: 0.8051 - val_macro_precision: 0.8215 - val_macro_recall: 0.8003 - val_top2_acc: 1.0000 - learning_rate: 6.0000e-07
# Epoch 17/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8761 - loss: 0.4660 - macro_auc: 0.9687 - macro_f1: 0.7984 - macro_precision: 0.7967 - macro_recall: 0.8020 - top2_acc: 0.9930
# Epoch 17: val_macro_f1 did not improve from 0.80508
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 396s 5s/step - acc: 0.8737 - loss: 0.4926 - macro_auc: 0.9682 - macro_f1: 0.7842 - macro_precision: 0.7816 - macro_recall: 0.7884 - top2_acc: 0.9879 - val_acc: 0.8952 - val_loss: 0.3018 - val_macro_auc: 0.9788 - val_macro_f1: 0.8051 - val_macro_precision: 0.8215 - val_macro_recall: 0.8003 - val_top2_acc: 1.0000 - learning_rate: 6.0000e-07
# Epoch 18/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8508 - loss: 0.5030 - macro_auc: 0.9635 - macro_f1: 0.7414 - macro_precision: 0.7408 - macro_recall: 0.7465 - top2_acc: 0.9860
# Epoch 18: val_macro_f1 did not improve from 0.80508
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.8000000636675396e-07.
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 394s 5s/step - acc: 0.8685 - loss: 0.4815 - macro_auc: 0.9690 - macro_f1: 0.7854 - macro_precision: 0.7822 - macro_recall: 0.7921 - top2_acc: 0.9896 - val_acc: 0.8952 - val_loss: 0.2997 - val_macro_auc: 0.9786 - val_macro_f1: 0.8051 - val_macro_precision: 0.8215 - val_macro_recall: 0.8003 - val_top2_acc: 1.0000 - learning_rate: 6.0000e-07
# Epoch 19/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8708 - loss: 0.5090 - macro_auc: 0.9653 - macro_f1: 0.7793 - macro_precision: 0.7847 - macro_recall: 0.7946 - top2_acc: 0.9892
# Epoch 19: val_macro_f1 did not improve from 0.80508
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 395s 5s/step - acc: 0.8668 - loss: 0.5104 - macro_auc: 0.9649 - macro_f1: 0.7745 - macro_precision: 0.7738 - macro_recall: 0.7832 - top2_acc: 0.9844 - val_acc: 0.8952 - val_loss: 0.2993 - val_macro_auc: 0.9787 - val_macro_f1: 0.8051 - val_macro_precision: 0.8215 - val_macro_recall: 0.8003 - val_top2_acc: 1.0000 - learning_rate: 1.8000e-07
# Epoch 20/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8920 - loss: 0.4023 - macro_auc: 0.9744 - macro_f1: 0.8118 - macro_precision: 0.8085 - macro_recall: 0.8221 - top2_acc: 0.9940
# Epoch 20: val_macro_f1 did not improve from 0.80508
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 394s 5s/step - acc: 0.8893 - loss: 0.4466 - macro_auc: 0.9721 - macro_f1: 0.8151 - macro_precision: 0.8128 - macro_recall: 0.8285 - top2_acc: 0.9862 - val_acc: 0.8952 - val_loss: 0.2992 - val_macro_auc: 0.9784 - val_macro_f1: 0.8051 - val_macro_precision: 0.8215 - val_macro_recall: 0.8003 - val_top2_acc: 1.0000 - learning_rate: 1.8000e-07
# Epoch 21/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - acc: 0.8601 - loss: 0.4869 - macro_auc: 0.9692 - macro_f1: 0.7781 - macro_precision: 0.7761 - macro_recall: 0.7817 - top2_acc: 0.9857
# Epoch 21: val_macro_f1 did not improve from 0.80508
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1e-07.
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 408s 6s/step - acc: 0.8616 - loss: 0.4968 - macro_auc: 0.9671 - macro_f1: 0.7704 - macro_precision: 0.7685 - macro_recall: 0.7737 - top2_acc: 0.9844 - val_acc: 0.8952 - val_loss: 0.2976 - val_macro_auc: 0.9786 - val_macro_f1: 0.8051 - val_macro_precision: 0.8215 - val_macro_recall: 0.8003 - val_top2_acc: 1.0000 - learning_rate: 1.8000e-07
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.

# %%
history_all = {}

for h in [history1, history2]:
    for key, values in h.history.items():
        if key not in history_all:
            history_all[key] = []
        history_all[key].extend(values)

stage1_epochs = len(history1.history["loss"])
total_epochs = len(history_all["loss"])

history_df = pd.DataFrame(history_all)
history_df.insert(0, "epoch", np.arange(1, total_epochs + 1))

history_df["stage"] = [
    "stage1" if i < stage1_epochs else "stage2"
    for i in range(total_epochs)
]

history_csv_path = REPORTS_DIR / "combined_training_history.csv"
history_df.to_csv(history_csv_path, index=False, encoding="utf-8-sig")

print("Saved:", history_csv_path)
history_df.head()
# Out:
# Saved: experiments\VGG16_20260419_185227\reports\combined_training_history.csv
#    epoch       acc      loss  macro_auc  macro_f1  macro_precision  \
# 0      1  0.467128  1.638604   0.689215  0.406429         0.423383
# 1      2  0.622837  1.067058   0.846950  0.541795         0.540573
# 2      3  0.692042  0.989060   0.879309  0.599304         0.599582
# 3      4  0.745675  0.794045   0.917337  0.655856         0.651792
# 4      5  0.785467  0.774467   0.924349  0.699034         0.695186
#
#    macro_recall  top2_acc   val_acc  val_loss  val_macro_auc  val_macro_f1  \
# 0      0.414894  0.717993  0.790323  0.645795       0.943019      0.586899
# 1      0.554610  0.871972  0.838710  0.462407       0.966588      0.681705
# 2      0.609050  0.887543  0.879032  0.435632       0.965691      0.707532
# 3      0.665396  0.922145  0.854839  0.416041       0.968236      0.748027
# 4      0.705194  0.937716  0.846774  0.410076       0.970293      0.736517
#
#    val_macro_precision  val_macro_recall  val_top2_acc  learning_rate   stage
# 0             0.555614          0.630187      0.911290         0.0002  stage1
# 1             0.838657          0.683856      0.959677         0.0002  stage1
# 2             0.889178          0.750481      0.991935         0.0002  stage1
# 3             0.752701          0.747444      0.983871         0.0002  stage1
# 4             0.781690          0.765486      0.983871         0.0002  stage1

# %%
plt.figure(figsize=(9, 5))

plt.plot(history_all["loss"], label="train_loss")
plt.plot(history_all["val_loss"], label="val_loss")

plt.axvline(
    stage1_epochs - 0.5,
    linestyle="--",
    label="fine-tune start"
)

plt.title("VGG16: Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, alpha=0.3)

out_path = PLOTS_DIR / "loss_curve.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)
# Out:
# Saved: experiments\VGG16_20260419_185227\plots\loss_curve.png

# %%
plt.figure(figsize=(9, 5))

plt.plot(history_all["acc"], label="train_acc")
plt.plot(history_all["val_acc"], label="val_acc")

plt.axvline(
    stage1_epochs - 0.5,
    linestyle="--",
    label="fine-tune start"
)

plt.title("VGG16: Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True, alpha=0.3)

out_path = PLOTS_DIR / "accuracy_curve.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)
# Out:
# Saved: experiments\VGG16_20260419_185227\plots\accuracy_curve.png

# %%
plt.figure(figsize=(9, 5))

plt.plot(history_all["macro_precision"], label="train_macro_precision")
plt.plot(history_all["val_macro_precision"], label="val_macro_precision")

plt.axvline(
    stage1_epochs - 0.5,
    linestyle="--",
    label="fine-tune start"
)

plt.title("VGG16: Macro Precision")
plt.xlabel("Epoch")
plt.ylabel("Macro Precision")
plt.legend()
plt.grid(True, alpha=0.3)

out_path = PLOTS_DIR / "macro_precision_curve.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)
# Out:
# Saved: experiments\VGG16_20260419_185227\plots\macro_precision_curve.png

# %%
plt.figure(figsize=(9, 5))

plt.plot(history_all["macro_recall"], label="train_macro_recall")
plt.plot(history_all["val_macro_recall"], label="val_macro_recall")

plt.axvline(
    stage1_epochs - 0.5,
    linestyle="--",
    label="fine-tune start"
)

plt.title("VGG16: Macro Recall")
plt.xlabel("Epoch")
plt.ylabel("Macro Recall")
plt.legend()
plt.grid(True, alpha=0.3)

out_path = PLOTS_DIR / "macro_recall_curve.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)
# Out:
# Saved: experiments\VGG16_20260419_185227\plots\macro_recall_curve.png

# %%
plt.figure(figsize=(9, 5))

plt.plot(history_all["macro_f1"], label="train_macro_f1")
plt.plot(history_all["val_macro_f1"], label="val_macro_f1")

plt.axvline(
    stage1_epochs - 0.5,
    linestyle="--",
    label="fine-tune start"
)

plt.title("VGG16: Macro F1")
plt.xlabel("Epoch")
plt.ylabel("Macro F1")
plt.legend()
plt.grid(True, alpha=0.3)

out_path = PLOTS_DIR / "macro_f1_curve.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)
# Out:
# Saved: experiments\VGG16_20260419_185227\plots\macro_f1_curve.png

# %%
plt.figure(figsize=(9, 5))

plt.plot(history_all["macro_auc"], label="train_macro_auc")
plt.plot(history_all["val_macro_auc"], label="val_macro_auc")

plt.axvline(
    stage1_epochs - 0.5,
    linestyle="--",
    label="fine-tune start"
)

plt.title("VGG16: Macro ROC-AUC")
plt.xlabel("Epoch")
plt.ylabel("Macro ROC-AUC")
plt.legend()
plt.grid(True, alpha=0.3)

out_path = PLOTS_DIR / "macro_auc_curve.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)
# Out:
# Saved: experiments\VGG16_20260419_185227\plots\macro_auc_curve.png

# %%
test_results = model.evaluate(test_ds, return_dict=True)

print("Test results:")
for key, value in test_results.items():
    print(f"{key}: {value:.4f}")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 78s 5s/step - acc: 0.8560 - loss: 0.3571 - macro_auc: 0.9723 - macro_f1: 0.7650 - macro_precision: 0.7748 - macro_recall: 0.7610 - top2_acc: 0.9920
# Test results:
# acc: 0.8560
# loss: 0.3571
# macro_auc: 0.9723
# macro_f1: 0.7650
# macro_precision: 0.7748
# macro_recall: 0.7610
# top2_acc: 0.9920

# %%
y_true = []
y_prob = []

for images, labels in test_ds:
    probs = model.predict(images, verbose=0)

    y_true.extend(labels.numpy().tolist())
    y_prob.extend(probs.tolist())

y_true = np.array(y_true)
y_prob = np.array(y_prob)
y_pred = np.argmax(y_prob, axis=1)

print("y_true:", y_true.shape)
print("y_prob:", y_prob.shape)
print("y_pred:", y_pred.shape)
# Out:
# y_true: (125,)
# y_prob: (125, 4)
# y_pred: (125,)

# %%
report_text = classification_report(
    y_true,
    y_pred,
    target_names=CLASS_NAMES,
    digits=4,
    zero_division=0
)

print(report_text)
# Out:
#               precision    recall  f1-score   support
#
#           24     0.9487    0.9024    0.9250        41
#           48     0.6667    0.5263    0.5882        19
#           72     0.5714    0.6154    0.5926        13
#      control     0.9123    1.0000    0.9541        52
#
#     accuracy                         0.8560       125
#    macro avg     0.7748    0.7610    0.7650       125
# weighted avg     0.8515    0.8560    0.8514       125

# %%
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=CLASS_NAMES
)

fig, ax = plt.subplots(figsize=(6, 6))
disp.plot(values_format="d", ax=ax)

plt.title("DenseNet121: Confusion Matrix")
plt.grid(False)

out_path = PLOTS_DIR / "confusion_matrix.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 disp = ConfusionMatrixDisplay(
# ----> 2     confusion_matrix=cm,
#       3     display_labels=CLASS_NAMES
#       4 )
#       6 fig, ax = plt.subplots(figsize=(6, 6))
#       7 disp.plot(values_format="d", ax=ax)
#
# NameError: name 'cm' is not defined

# %%
per_class_precision, per_class_recall, per_class_f1, per_class_support = (
    precision_recall_fscore_support(
        y_true,
        y_pred,
        labels=np.arange(NUM_CLASSES),
        zero_division=0
    )
)

per_class_df = pd.DataFrame({
    "class": CLASS_NAMES,
    "precision": per_class_precision,
    "recall": per_class_recall,
    "f1": per_class_f1,
    "support": per_class_support
})

per_class_path = REPORTS_DIR / "per_class_precision_recall_f1.csv"
per_class_df.to_csv(per_class_path, index=False, encoding="utf-8-sig")

print(per_class_df)
print("Saved:", per_class_path)

# %%
per_class_precision, per_class_recall, per_class_f1, per_class_support = (
    precision_recall_fscore_support(
        y_true,
        y_pred,
        labels=np.arange(NUM_CLASSES),
        zero_division=0
    )
)

per_class_df = pd.DataFrame({
    "class": CLASS_NAMES,
    "precision": per_class_precision,
    "recall": per_class_recall,
    "f1": per_class_f1,
    "support": per_class_support
})

per_class_path = REPORTS_DIR / "per_class_precision_recall_f1.csv"
per_class_df.to_csv(per_class_path, index=False, encoding="utf-8-sig")

print(per_class_df)
print("Saved:", per_class_path)

# %%
x = np.arange(NUM_CLASSES)
width = 0.25

plt.figure(figsize=(10, 5))

plt.bar(
    x - width,
    per_class_df["precision"],
    width,
    label="Precision"
)

plt.bar(
    x,
    per_class_df["recall"],
    width,
    label="Recall"
)

plt.bar(
    x + width,
    per_class_df["f1"],
    width,
    label="F1"
)

plt.xticks(x, CLASS_NAMES)
plt.ylim(0, 1.05)

plt.title("DenseNet121: Per-class Precision / Recall / F1")
plt.xlabel("Class")
plt.ylabel("Score")
plt.legend()
plt.grid(axis="y", alpha=0.3)

out_path = PLOTS_DIR / "per_class_precision_recall_f1.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)

# %%
y_true_bin = label_binarize(
    y_true,
    classes=np.arange(NUM_CLASSES)
)

plt.figure(figsize=(8, 6))

per_class_auc = {}

for i, class_name in enumerate(CLASS_NAMES):
    fpr, tpr, _ = roc_curve(
        y_true_bin[:, i],
        y_prob[:, i]
    )

    class_auc = auc(fpr, tpr)
    per_class_auc[class_name] = float(class_auc)

    plt.plot(
        fpr,
        tpr,
        label=f"{class_name} AUC={class_auc:.3f}"
    )

plt.plot(
    [0, 1],
    [0, 1],
    linestyle="--",
    label="chance"
)

plt.title("DenseNet121: ROC Curves by Class")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(True, alpha=0.3)

out_path = PLOTS_DIR / "roc_curves_by_class.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)

for cls, value in per_class_auc.items():
    print(f"{cls:>8}: {value:.4f}")

# %%
plt.figure(figsize=(8, 6))

per_class_average_precision = {}

for i, class_name in enumerate(CLASS_NAMES):
    precision_curve, recall_curve, _ = precision_recall_curve(
        y_true_bin[:, i],
        y_prob[:, i]
    )

    avg_precision = average_precision_score(
        y_true_bin[:, i],
        y_prob[:, i]
    )

    per_class_average_precision[class_name] = float(avg_precision)

    plt.plot(
        recall_curve,
        precision_curve,
        label=f"{class_name} AP={avg_precision:.3f}"
    )

plt.title("DenseNet121: Precision-Recall Curves by Class")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.ylim(0, 1.05)
plt.xlim(0, 1.0)
plt.legend()
plt.grid(True, alpha=0.3)

out_path = PLOTS_DIR / "precision_recall_curves_by_class.png"
plt.savefig(out_path, dpi=160, bbox_inches="tight")
plt.show()

print("Saved:", out_path)

for cls, value in per_class_average_precision.items():
    print(f"{cls:>8}: AP={value:.4f}")
